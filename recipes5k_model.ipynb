# %% [markdown]
# ### Recipes 5k
#
# * [Dataset](http://www.ub.edu/cvub/recipes5k/)
#
# * [Original Paper](https://www.researchgate.net/publication/318729535_Food_Ingredients_Recognition_through_Multi-label_Learning)

# %% [markdown]
# ### Setup Environment:

# %%
import os
import pandas as pd

from src.classifiers import preprocess_data, process_labels,split_data

from src.classifiers import VQADataset
from torch.utils.data import DataLoader

from src.classifiers import train_early_fusion, train_late_fusion

# %%
PATH = 'Embeddings/Recipes5k/'
COLUMN = 'embeddings'

# %%
text_path, images_path = os.listdir(PATH)

# %% [markdown]
# ## Get data

# %% [markdown]
# ### Text

# %%
text = pd.read_csv(os.path.join(PATH, text_path))
text
# Out:
#                                                   image                class  \
# 0     onion_rings/0_einkorn_onion_rings_hostedLargeU...          onion_rings
# 1     onion_rings/1_crispy_onion_rings_hostedLargeUr...          onion_rings
# 2          onion_rings/2_onion_rings_hostedLargeUrl.jpg          onion_rings
# 3          onion_rings/3_onion_rings_hostedLargeUrl.jpg          onion_rings
# 4          onion_rings/4_onion_rings_hostedLargeUrl.jpg          onion_rings
# ...                                                 ...                  ...
# 4821  chocolate_ice_cream/45_chocolate_ice_cream_hos...  chocolate_ice_cream
# 4822  chocolate_ice_cream/46_dark_chocolate_ice_crea...  chocolate_ice_cream
# 4823  chocolate_ice_cream/47_the_darkest_chocolate_i...  chocolate_ice_cream
# 4824  chocolate_ice_cream/48_homemade_chocolate_ice_...  chocolate_ice_cream
# 4825  chocolate_ice_cream/49_mint_chocolate_ice_crea...  chocolate_ice_cream
#
#       split                                        ingredients  \
# 0       val  yellow onion,flour,baking powder,seasoning sal...
# 1     train  white onion,panko,cornmeal,ground paprika,onio...
# 2     train  yellow onion,all-purpose flour,baking powder,l...
# 3     train                      oil,pancake mix,spanish onion
# 4     train  peanut oil,sweet onion,flour,eggs,celery salt,...
# ...     ...                                                ...
# 4821  train  dark chocolate,whole milk,unsweetened cocoa po...
# 4822  train  half & half,whole milk,heavy cream,sugar,sea s...
# 4823  train  unsweetened cocoa powder,brewed coffee,granula...
# 4824  train  unsweetened cocoa powder,sugar,firmly packed b...
# 4825  train  fresh mint,heavy cream,whole milk,dark chocola...
#
#                                              embeddings
# 0     [1.1028140783309937, -1.5013680458068848, -0.3...
# 1     [0.2510446310043335, -0.8487659692764282, -0.7...
# 2     [0.6824526786804199, -1.090896487236023, 0.987...
# 3     [2.3841049671173096, -5.021180629730225, -0.17...
# 4     [2.3817403316497803, 0.37943604588508606, -3.5...
# ...                                                 ...
# 4821  [1.4988073110580444, -0.4912002980709076, 1.06...
# 4822  [0.7600823640823364, 0.5964796543121338, 0.303...
# 4823  [1.6432948112487793, -1.712591290473938, 1.486...
# 4824  [2.056760549545288, -1.5574166774749756, -0.36...
# 4825  [1.8116297721862793, -0.04311274364590645, -1....
#
# [4826 rows x 5 columns]

# %% [markdown]
# ### Images

# %%
images = pd.read_csv(os.path.join(PATH, images_path))
images.head()
# Out:
#                                            ImageName         0         1  \
# 0  onion_rings/0_einkorn_onion_rings_hostedLargeU...  5.255562 -1.102281
# 1  onion_rings/1_crispy_onion_rings_hostedLargeUr... -0.180872  0.357785
# 2       onion_rings/2_onion_rings_hostedLargeUrl.jpg  5.125897 -0.426740
# 3       onion_rings/3_onion_rings_hostedLargeUrl.jpg  4.048971 -0.883851
# 4       onion_rings/4_onion_rings_hostedLargeUrl.jpg  2.488026  2.054659
#
#           2         3         4         5         6         7         8  ...  \
# 0  3.221878 -0.848734  1.142476  1.436065  0.303136 -2.795287 -1.534621  ...
# 1  2.953790 -0.514284  3.046458  3.261230 -0.069414 -2.036384 -0.755874  ...
# 2  3.452004 -2.458713  1.216147  0.867196  0.016434 -1.605688 -1.242954  ...
# 3  3.259991 -1.269905  2.037031  0.474060  2.139239 -1.652627 -1.356481  ...
# 4  3.591714 -2.157786  0.088067  2.232692  0.783981 -2.377056  1.325430  ...
#
#         758       759       760       761       762       763       764  \
# 0  0.145026 -0.173223 -1.631687 -1.373413 -1.700477  2.993020 -0.123423
# 1  1.585758  1.397843 -2.597118 -1.620306  1.528063 -1.035716  1.339101
# 2  0.984198  1.104070 -2.185897  0.033494 -1.515771  2.490174 -1.488795
# 3  0.464018  0.658732 -1.866643 -0.403469 -0.583548  2.141593  0.015457
# 4  0.527386  0.913060 -2.255255  0.041726 -0.814133  1.396166  0.624918
#
#         765       766       767
# 0  0.482150  0.335781  0.164388
# 1 -1.978144 -0.381255 -0.014164
# 2  1.110195  0.044147  0.145058
# 3  0.862089 -1.321241  0.749305
# 4  0.262062 -0.816889 -1.154006
#
# [5 rows x 769 columns]

# %% [markdown]
# ### Merge and preprocess the datasets

# %%
df = preprocess_data(text, images, "image", "ImageName")
df.head()
# Out:
#          class  split                                        ingredients  \
# 0  onion_rings    val  yellow onion,flour,baking powder,seasoning sal...
# 1  onion_rings  train  white onion,panko,cornmeal,ground paprika,onio...
# 2  onion_rings  train  yellow onion,all-purpose flour,baking powder,l...
# 3  onion_rings  train                      oil,pancake mix,spanish onion
# 4  onion_rings  train  peanut oil,sweet onion,flour,eggs,celery salt,...
#
#      text_1    text_2    text_3    text_4    text_5    text_6    text_7  ...  \
# 0  1.102814 -1.501368 -0.301835 -1.239182 -0.910469 -0.634073  0.839440  ...
# 1  0.251045 -0.848766 -0.742973 -1.274160 -2.171595  0.156482 -0.167365  ...
# 2  0.682453 -1.090896  0.987037 -0.275286 -2.029299 -0.240013  1.039339  ...
# 3  2.384105 -5.021181 -0.179801 -0.909381  0.369275 -1.475059  0.131486  ...
# 4  2.381740  0.379436 -3.507455  0.028276  0.625003  1.816234 -1.526726  ...
#
#    image_758  image_759  image_760  image_761  image_762  image_763  \
# 0   0.145026  -0.173223  -1.631687  -1.373413  -1.700477   2.993020
# 1   1.585758   1.397843  -2.597118  -1.620306   1.528063  -1.035716
# 2   0.984198   1.104070  -2.185897   0.033494  -1.515771   2.490174
# 3   0.464018   0.658732  -1.866643  -0.403469  -0.583548   2.141593
# 4   0.527386   0.913060  -2.255255   0.041726  -0.814133   1.396166
#
#    image_764  image_765  image_766  image_767
# 0  -0.123423   0.482150   0.335781   0.164388
# 1   1.339101  -1.978144  -0.381255  -0.014164
# 2  -1.488795   1.110195   0.044147   0.145058
# 3   0.015457   0.862089  -1.321241   0.749305
# 4   0.624918   0.262062  -0.816889  -1.154006
#
# [5 rows x 4867 columns]

# %% [markdown]
# ## Data Perparation

# %%
# Split the data
train_df, test_df = split_data(df)

# Select features and labels vectors
text_columns = [column for column in df.columns if 'text' in column] #[f'text_{i}']
image_columns = [column for column in df.columns if 'image' in column] #[f'image_{i}']
label_columns = 'class'


# Process and one-hot encode labels for training set
train_labels, mlb, train_columns = process_labels(train_df, col=label_columns)
test_labels = process_labels(test_df, col=label_columns, train_columns=train_columns)


train_dataset = VQADataset(train_df, text_columns, image_columns, label_columns, mlb, train_columns)
test_dataset = VQADataset(test_df, text_columns, image_columns, label_columns, mlb, train_columns)


train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)
# Out:
# Train Shape: (3409, 4867)
# Test Shape: (783, 4867)

# %% [markdown]
# ### Models

# %%
text_input_size = len(text_columns)
image_input_size = len(image_columns)
output_size = len(mlb.classes_)
multilabel = False

# %%
# Train early fusion model
print("Training Early Fusion Model:")

train_early_fusion(train_loader, test_loader, text_input_size, image_input_size, output_size, num_epochs=15, multilabel=multilabel, report=True)
# Out:
# Training Early Fusion Model:
# Epoch 1/15 - Test Accuracy: 0.5734
# Epoch 2/15 - Test Accuracy: 0.6973
# Epoch 3/15 - Test Accuracy: 0.7356
# Epoch 4/15 - Test Accuracy: 0.7356
# Epoch 5/15 - Test Accuracy: 0.7369
# Epoch 6/15 - Test Accuracy: 0.7599
# Epoch 7/15 - Test Accuracy: 0.7599
# Epoch 8/15 - Test Accuracy: 0.7663
# Epoch 9/15 - Test Accuracy: 0.7739
# Epoch 10/15 - Test Accuracy: 0.7676
# Epoch 11/15 - Test Accuracy: 0.7739
# Epoch 12/15 - Test Accuracy: 0.7829
# Epoch 13/15 - Test Accuracy: 0.7752
# Epoch 14/15 - Test Accuracy: 0.7816
# Epoch 15/15 - Test Accuracy: 0.7727
#               precision    recall  f1-score   support
#
#            0       1.00      0.75      0.86         8
#            1       1.00      0.75      0.86         8
#            2       1.00      1.00      1.00         8
#            3       1.00      0.60      0.75         5
#            4       0.71      0.62      0.67         8
#            5       0.50      0.29      0.36         7
#            6       0.60      0.75      0.67         8
#            7       1.00      1.00      1.00         8
#            8       1.00      0.88      0.93         8
#            9       0.60      0.75      0.67         8
#           10       0.67      1.00      0.80         8
#           11       0.78      0.88      0.82         8
#           12       1.00      1.00      1.00         8
#           13       0.70      0.88      0.78         8
#           14       0.88      0.88      0.88         8
#           15       1.00      0.75      0.86         8
#           16       0.89      1.00      0.94         8
#           17       0.11      0.12      0.12         8
#           18       0.55      0.75      0.63         8
#           19       0.80      1.00      0.89         8
#           20       0.88      0.88      0.88         8
#           21       0.89      1.00      0.94         8
#           22       0.80      0.50      0.62         8
#           23       1.00      0.88      0.93         8
#           24       0.57      0.50      0.53         8
#           25       1.00      1.00      1.00         8
#           26       0.83      0.62      0.71         8
#           27       1.00      0.62      0.77         8
#           28       0.86      0.75      0.80         8
#           29       1.00      1.00      1.00         8
#           30       0.89      1.00      0.94         8
#           31       0.78      0.88      0.82         8
#           32       0.89      1.00      0.94         8
#           33       1.00      1.00      1.00         8
#           34       0.83      0.62      0.71         8
#           35       1.00      0.62      0.77         8
#           36       0.88      0.88      0.88         8
#           37       0.67      0.50      0.57         4
#           38       0.83      0.62      0.71         8
#           39       1.00      0.38      0.55         8
#           40       0.58      0.88      0.70         8
#           41       0.12      0.12      0.12         8
#           42       0.57      0.50      0.53         8
#           43       0.89      1.00      0.94         8
#           44       0.71      0.62      0.67         8
#           45       1.00      0.50      0.67         6
#           46       1.00      0.75      0.86         8
#           47       0.86      0.75      0.80         8
#           48       0.88      0.88      0.88         8
#           49       1.00      0.62      0.77         8
#           50       0.78      0.88      0.82         8
#           51       0.67      1.00      0.80         8
#           52       0.50      1.00      0.67         8
#           53       0.78      0.88      0.82         8
#           54       0.60      0.86      0.71         7
#           55       0.67      0.50      0.57         8
#           56       0.67      0.75      0.71         8
#           57       1.00      1.00      1.00         8
#           58       1.00      0.75      0.86         8
#           59       1.00      0.62      0.77         8
#           60       1.00      0.75      0.86         8
#           61       0.88      0.88      0.88         8
#           62       1.00      0.75      0.86         4
#           63       0.80      1.00      0.89         8
#           64       1.00      1.00      1.00         8
#           65       0.78      0.88      0.82         8
#           66       1.00      1.00      1.00         8
#           67       0.73      1.00      0.84         8
#           68       0.83      0.62      0.71         8
#           69       0.80      1.00      0.89         8
#           70       0.88      0.88      0.88         8
#           71       0.89      1.00      0.94         8
#           72       1.00      1.00      1.00         8
#           73       0.86      0.75      0.80         8
#           74       0.64      0.88      0.74         8
#           75       0.40      0.33      0.36         6
#           76       0.70      0.88      0.78         8
#           77       0.78      0.88      0.82         8
#           78       0.45      0.62      0.53         8
#           79       0.75      0.75      0.75         8
#           80       0.67      0.75      0.71         8
#           81       0.73      1.00      0.84         8
#           82       0.86      0.75      0.80         8
#           83       0.80      1.00      0.89         8
#           84       0.73      1.00      0.84         8
#           85       0.71      0.62      0.67         8
#           86       0.88      0.88      0.88         8
#           87       0.50      0.25      0.33         8
#           88       1.00      0.75      0.86         8
#           89       0.60      0.38      0.46         8
#           90       1.00      1.00      1.00         8
#           91       1.00      0.88      0.93         8
#           92       0.80      1.00      0.89         8
#           93       0.80      1.00      0.89         8
#           94       0.18      0.25      0.21         8
#           95       1.00      0.62      0.77         8
#           96       0.70      0.88      0.78         8
#           97       1.00      0.50      0.67         2
#           98       1.00      1.00      1.00         8
#           99       1.00      0.33      0.50         6
#          100       0.89      1.00      0.94         8
#
#     accuracy                           0.78       783
#    macro avg       0.81      0.78      0.78       783
# weighted avg       0.81      0.78      0.78       783

# %%
# Train late fusion model
print("Training Late Fusion Model:")
train_late_fusion(train_loader, test_loader, text_input_size, image_input_size, output_size, num_epochs=15, multilabel=multilabel, report=True)
# Out:
# Training Late Fusion Model:
# Epoch 1/15 - Test Accuracy: 0.5811
# Epoch 2/15 - Test Accuracy: 0.6999
# Epoch 3/15 - Test Accuracy: 0.7292
# Epoch 4/15 - Test Accuracy: 0.7395
# Epoch 5/15 - Test Accuracy: 0.7701
# Epoch 6/15 - Test Accuracy: 0.7599
# Epoch 7/15 - Test Accuracy: 0.7854
# Epoch 8/15 - Test Accuracy: 0.7752
# Epoch 9/15 - Test Accuracy: 0.7880
# Epoch 10/15 - Test Accuracy: 0.7829
# Epoch 11/15 - Test Accuracy: 0.7969
# Epoch 12/15 - Test Accuracy: 0.7905
# Epoch 13/15 - Test Accuracy: 0.8033
# Epoch 14/15 - Test Accuracy: 0.7982
# Epoch 15/15 - Test Accuracy: 0.8008
#               precision    recall  f1-score   support
#
#            0       1.00      0.75      0.86         8
#            1       1.00      1.00      1.00         8
#            2       0.89      1.00      0.94         8
#            3       1.00      0.60      0.75         5
#            4       0.67      0.75      0.71         8
#            5       0.60      0.43      0.50         7
#            6       1.00      0.75      0.86         8
#            7       1.00      1.00      1.00         8
#            8       1.00      0.88      0.93         8
#            9       0.55      0.75      0.63         8
#           10       0.67      1.00      0.80         8
#           11       0.89      1.00      0.94         8
#           12       1.00      1.00      1.00         8
#           13       0.64      0.88      0.74         8
#           14       1.00      1.00      1.00         8
#           15       0.88      0.88      0.88         8
#           16       0.80      1.00      0.89         8
#           17       0.20      0.25      0.22         8
#           18       0.71      0.62      0.67         8
#           19       1.00      1.00      1.00         8
#           20       1.00      0.62      0.77         8
#           21       0.89      1.00      0.94         8
#           22       0.80      0.50      0.62         8
#           23       0.88      0.88      0.88         8
#           24       1.00      0.75      0.86         8
#           25       0.89      1.00      0.94         8
#           26       0.86      0.75      0.80         8
#           27       0.75      0.75      0.75         8
#           28       0.78      0.88      0.82         8
#           29       1.00      1.00      1.00         8
#           30       0.80      1.00      0.89         8
#           31       0.88      0.88      0.88         8
#           32       1.00      1.00      1.00         8
#           33       0.80      1.00      0.89         8
#           34       1.00      0.50      0.67         8
#           35       1.00      0.75      0.86         8
#           36       1.00      0.88      0.93         8
#           37       1.00      0.25      0.40         4
#           38       0.71      0.62      0.67         8
#           39       0.88      0.88      0.88         8
#           40       0.86      0.75      0.80         8
#           41       0.60      0.38      0.46         8
#           42       0.80      0.50      0.62         8
#           43       0.89      1.00      0.94         8
#           44       0.55      0.75      0.63         8
#           45       1.00      0.50      0.67         6
#           46       0.88      0.88      0.88         8
#           47       1.00      0.88      0.93         8
#           48       1.00      0.62      0.77         8
#           49       0.80      0.50      0.62         8
#           50       0.78      0.88      0.82         8
#           51       0.73      1.00      0.84         8
#           52       0.55      0.75      0.63         8
#           53       1.00      0.75      0.86         8
#           54       0.62      0.71      0.67         7
#           55       0.67      0.75      0.71         8
#           56       0.62      1.00      0.76         8
#           57       1.00      1.00      1.00         8
#           58       0.88      0.88      0.88         8
#           59       0.88      0.88      0.88         8
#           60       1.00      1.00      1.00         8
#           61       0.88      0.88      0.88         8
#           62       1.00      0.50      0.67         4
#           63       0.88      0.88      0.88         8
#           64       0.89      1.00      0.94         8
#           65       1.00      0.88      0.93         8
#           66       0.80      1.00      0.89         8
#           67       0.80      1.00      0.89         8
#           68       1.00      0.75      0.86         8
#           69       0.80      1.00      0.89         8
#           70       1.00      0.88      0.93         8
#           71       0.89      1.00      0.94         8
#           72       1.00      1.00      1.00         8
#           73       0.86      0.75      0.80         8
#           74       0.80      1.00      0.89         8
#           75       0.50      0.50      0.50         6
#           76       0.88      0.88      0.88         8
#           77       0.67      1.00      0.80         8
#           78       0.50      0.50      0.50         8
#           79       0.80      1.00      0.89         8
#           80       0.78      0.88      0.82         8
#           81       1.00      1.00      1.00         8
#           82       0.78      0.88      0.82         8
#           83       1.00      1.00      1.00         8
#           84       0.73      1.00      0.84         8
#           85       0.88      0.88      0.88         8
#           86       0.88      0.88      0.88         8
#           87       0.40      0.25      0.31         8
#           88       0.60      0.75      0.67         8
#           89       0.67      0.50      0.57         8
#           90       1.00      1.00      1.00         8
#           91       1.00      1.00      1.00         8
#           92       0.89      1.00      0.94         8
#           93       0.89      1.00      0.94         8
#           94       0.60      0.38      0.46         8
#           95       0.86      0.75      0.80         8
#           96       0.67      0.75      0.71         8
#           97       0.00      0.00      0.00         2
#           98       1.00      0.88      0.93         8
#           99       0.80      0.67      0.73         6
#          100       0.89      1.00      0.94         8
#
#     accuracy                           0.82       783
#    macro avg       0.83      0.81      0.80       783
# weighted avg       0.83      0.82      0.82       783
# /home/datascience/conda/retina_embeddings_v0_0_1/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/datascience/conda/retina_embeddings_v0_0_1/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/datascience/conda/retina_embeddings_v0_0_1/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/datascience/conda/retina_embeddings_v0_0_1/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
