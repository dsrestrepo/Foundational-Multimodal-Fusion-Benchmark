# %% [markdown]
# ### Recipes 5k
#
# * [Dataset](http://www.ub.edu/cvub/recipes5k/)
#
# * [Original Paper](https://www.researchgate.net/publication/318729535_Food_Ingredients_Recognition_through_Multi-label_Learning)

# %%
# %cd ..

# %% [markdown]
# ### Setup Environment:

# %%
import os
import pandas as pd

from src.classifiers import preprocess_data, process_labels,split_data

from src.classifiers import VQADataset
from torch.utils.data import DataLoader

from src.classifiers_cpu_metrics import train_early_fusion, train_late_fusion

# %%
PATH = 'Embeddings/Recipes5k/'
COLUMN = 'embeddings'

# %%
text_path, images_path = os.listdir(PATH)

# %% [markdown]
# ## Get data

# %% [markdown]
# ### Text

# %%
text = pd.read_csv(os.path.join(PATH, text_path))
text
# Out:
#                                                   image                class  \
# 0     onion_rings/0_einkorn_onion_rings_hostedLargeU...          onion_rings
# 1     onion_rings/1_crispy_onion_rings_hostedLargeUr...          onion_rings
# 2          onion_rings/2_onion_rings_hostedLargeUrl.jpg          onion_rings
# 3          onion_rings/3_onion_rings_hostedLargeUrl.jpg          onion_rings
# 4          onion_rings/4_onion_rings_hostedLargeUrl.jpg          onion_rings
# ...                                                 ...                  ...
# 4821  chocolate_ice_cream/45_chocolate_ice_cream_hos...  chocolate_ice_cream
# 4822  chocolate_ice_cream/46_dark_chocolate_ice_crea...  chocolate_ice_cream
# 4823  chocolate_ice_cream/47_the_darkest_chocolate_i...  chocolate_ice_cream
# 4824  chocolate_ice_cream/48_homemade_chocolate_ice_...  chocolate_ice_cream
# 4825  chocolate_ice_cream/49_mint_chocolate_ice_crea...  chocolate_ice_cream
#
#       split                                        ingredients  \
# 0       val  yellow onion,flour,baking powder,seasoning sal...
# 1     train  white onion,panko,cornmeal,ground paprika,onio...
# 2     train  yellow onion,all-purpose flour,baking powder,l...
# 3     train                      oil,pancake mix,spanish onion
# 4     train  peanut oil,sweet onion,flour,eggs,celery salt,...
# ...     ...                                                ...
# 4821  train  dark chocolate,whole milk,unsweetened cocoa po...
# 4822  train  half & half,whole milk,heavy cream,sugar,sea s...
# 4823  train  unsweetened cocoa powder,brewed coffee,granula...
# 4824  train  unsweetened cocoa powder,sugar,firmly packed b...
# 4825  train  fresh mint,heavy cream,whole milk,dark chocola...
#
#                                              embeddings
# 0     [1.1028140783309937, -1.5013680458068848, -0.3...
# 1     [0.2510446310043335, -0.8487659692764282, -0.7...
# 2     [0.6824526786804199, -1.090896487236023, 0.987...
# 3     [2.3841049671173096, -5.021180629730225, -0.17...
# 4     [2.3817403316497803, 0.37943604588508606, -3.5...
# ...                                                 ...
# 4821  [1.4988073110580444, -0.4912002980709076, 1.06...
# 4822  [0.7600823640823364, 0.5964796543121338, 0.303...
# 4823  [1.6432948112487793, -1.712591290473938, 1.486...
# 4824  [2.056760549545288, -1.5574166774749756, -0.36...
# 4825  [1.8116297721862793, -0.04311274364590645, -1....
#
# [4826 rows x 5 columns]

# %% [markdown]
# ### Images

# %%
images = pd.read_csv(os.path.join(PATH, images_path))
images.head()
# Out:
#                                            ImageName         0         1  \
# 0  onion_rings/0_einkorn_onion_rings_hostedLargeU...  5.255562 -1.102281
# 1  onion_rings/1_crispy_onion_rings_hostedLargeUr... -0.180872  0.357785
# 2       onion_rings/2_onion_rings_hostedLargeUrl.jpg  5.125897 -0.426740
# 3       onion_rings/3_onion_rings_hostedLargeUrl.jpg  4.048971 -0.883851
# 4       onion_rings/4_onion_rings_hostedLargeUrl.jpg  2.488026  2.054659
#
#           2         3         4         5         6         7         8  ...  \
# 0  3.221878 -0.848734  1.142476  1.436065  0.303136 -2.795287 -1.534621  ...
# 1  2.953790 -0.514284  3.046458  3.261230 -0.069414 -2.036384 -0.755874  ...
# 2  3.452004 -2.458713  1.216147  0.867196  0.016434 -1.605688 -1.242954  ...
# 3  3.259991 -1.269905  2.037031  0.474060  2.139239 -1.652627 -1.356481  ...
# 4  3.591714 -2.157786  0.088067  2.232692  0.783981 -2.377056  1.325430  ...
#
#         758       759       760       761       762       763       764  \
# 0  0.145026 -0.173223 -1.631687 -1.373413 -1.700477  2.993020 -0.123423
# 1  1.585758  1.397843 -2.597118 -1.620306  1.528063 -1.035716  1.339101
# 2  0.984198  1.104070 -2.185897  0.033494 -1.515771  2.490174 -1.488795
# 3  0.464018  0.658732 -1.866643 -0.403469 -0.583548  2.141593  0.015457
# 4  0.527386  0.913060 -2.255255  0.041726 -0.814133  1.396166  0.624918
#
#         765       766       767
# 0  0.482150  0.335781  0.164388
# 1 -1.978144 -0.381255 -0.014164
# 2  1.110195  0.044147  0.145058
# 3  0.862089 -1.321241  0.749305
# 4  0.262062 -0.816889 -1.154006
#
# [5 rows x 769 columns]

# %% [markdown]
# ### Merge and preprocess the datasets

# %%
df = preprocess_data(text, images, "image", "ImageName")
df.head()
# Out:
#          class  split                                        ingredients  \
# 0  onion_rings    val  yellow onion,flour,baking powder,seasoning sal...
# 1  onion_rings  train  white onion,panko,cornmeal,ground paprika,onio...
# 2  onion_rings  train  yellow onion,all-purpose flour,baking powder,l...
# 3  onion_rings  train                      oil,pancake mix,spanish onion
# 4  onion_rings  train  peanut oil,sweet onion,flour,eggs,celery salt,...
#
#      text_1    text_2    text_3    text_4    text_5    text_6    text_7  ...  \
# 0  1.102814 -1.501368 -0.301835 -1.239182 -0.910469 -0.634073  0.839440  ...
# 1  0.251045 -0.848766 -0.742973 -1.274160 -2.171595  0.156482 -0.167365  ...
# 2  0.682453 -1.090896  0.987037 -0.275286 -2.029299 -0.240013  1.039339  ...
# 3  2.384105 -5.021181 -0.179801 -0.909381  0.369275 -1.475059  0.131486  ...
# 4  2.381740  0.379436 -3.507455  0.028276  0.625003  1.816234 -1.526726  ...
#
#    image_758  image_759  image_760  image_761  image_762  image_763  \
# 0   0.145026  -0.173223  -1.631687  -1.373413  -1.700477   2.993020
# 1   1.585758   1.397843  -2.597118  -1.620306   1.528063  -1.035716
# 2   0.984198   1.104070  -2.185897   0.033494  -1.515771   2.490174
# 3   0.464018   0.658732  -1.866643  -0.403469  -0.583548   2.141593
# 4   0.527386   0.913060  -2.255255   0.041726  -0.814133   1.396166
#
#    image_764  image_765  image_766  image_767
# 0  -0.123423   0.482150   0.335781   0.164388
# 1   1.339101  -1.978144  -0.381255  -0.014164
# 2  -1.488795   1.110195   0.044147   0.145058
# 3   0.015457   0.862089  -1.321241   0.749305
# 4   0.624918   0.262062  -0.816889  -1.154006
#
# [5 rows x 4867 columns]

# %% [markdown]
# ## Data Perparation

# %%
# Split the data
train_df, test_df = split_data(df)

# Select features and labels vectors
text_columns = [column for column in df.columns if 'text' in column] #[f'text_{i}']
image_columns = [column for column in df.columns if 'image' in column] #[f'image_{i}']
label_columns = 'class'


# Process and one-hot encode labels for training set
train_labels, mlb, train_columns = process_labels(train_df, col=label_columns)
test_labels = process_labels(test_df, col=label_columns, train_columns=train_columns)


train_dataset = VQADataset(train_df, text_columns, image_columns, label_columns, mlb, train_columns)
test_dataset = VQADataset(test_df, text_columns, image_columns, label_columns, mlb, train_columns)


train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=2)
# Out:
# Train Shape: (3409, 4867)
# Test Shape: (783, 4867)

# %% [markdown]
# ### Models

# %%
text_input_size = len(text_columns)
image_input_size = len(image_columns)
output_size = len(mlb.classes_)
multilabel = False

# %%
# Train early fusion model
print("Training Early Fusion Model:")

train_early_fusion(train_loader, test_loader, text_input_size, image_input_size, output_size, num_epochs=2, multilabel=multilabel, report=True)
# Out:
# Training Early Fusion Model:
# Model Memory Usage: 2.43 MB
# Single Batch Memory Usage: 1.21 MB
# The number of parameters of the model are: 636005
# STAGE:2024-02-01 14:47:17 1413:1413 ActivityProfilerController.cpp:312] Completed Stage: Warm Up
# Epoch 1/2 - Test Accuracy: 0.6513
# Epoch 1/2 - Training Time: 0.46 seconds | Inference Time: 0.12 seconds
# Epoch 2/2 - Test Accuracy: 0.7625
# Epoch 2/2 - Training Time: 0.39 seconds | Inference Time: 0.13 seconds
# STAGE:2024-02-01 14:47:19 1413:1413 ActivityProfilerController.cpp:318] Completed Stage: Collection
# STAGE:2024-02-01 14:47:19 1413:1413 ActivityProfilerController.cpp:322] Completed Stage: Post Processing
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg       CPU Mem  Self CPU Mem    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                          training_batch         8.86%      83.949ms        60.08%     569.439ms       5.273ms    -121.49 Mb    -132.18 Mb           108
# enumerate(DataLoader)#_MultiProcessingDataLoaderIter...        34.34%     325.443ms        34.68%     328.715ms       2.382ms     158.74 Mb     158.69 Mb           138
#                                    DataParallel.forward         2.99%      28.376ms        19.53%     185.090ms       1.381ms     143.16 Mb     -34.91 Mb           134
#                               Optimizer.step#AdamW.step         4.98%      47.167ms        18.89%     178.989ms       1.657ms       4.85 Mb    -507.27 Mb           108
#     autograd::engine::evaluate_function: AddmmBackward0         0.30%       2.818ms         8.61%      81.628ms     377.907us     129.46 Mb    -135.64 Mb           216
#                                          AddmmBackward0         0.21%       2.015ms         7.97%      75.492ms     349.500us     265.16 Mb           0 b           216
#                                            aten::linear         0.58%       5.532ms         7.73%      73.296ms     273.493us       7.32 Mb     176.75 Kb           268
#                                                aten::mm         7.44%      70.471ms         7.44%      70.471ms     217.503us     265.16 Mb     264.91 Mb           324
#                                             aten::addmm         6.48%      61.415ms         7.10%      67.328ms     251.224us       7.32 Mb       7.32 Mb           268
#                                         inference_batch         1.29%      12.206ms         5.09%      48.209ms       1.854ms     -28.55 Mb     -29.75 Mb            26
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 947.737ms
#
# Average Training Time per Epoch: 0.42 seconds
# Total Training Time per Epoch: 0.85 seconds
# Average Inference Time per Epoch: 0.12 seconds
# Total Inference Time per Epoch: 0.24 seconds
#               precision    recall  f1-score   support
#
#            0       1.00      0.75      0.86         8
#            1       0.44      0.88      0.58         8
#            2       0.80      1.00      0.89         8
#            3       1.00      0.60      0.75         5
#            4       0.62      0.62      0.62         8
#            5       0.00      0.00      0.00         7
#            6       0.75      0.75      0.75         8
#            7       1.00      1.00      1.00         8
#            8       0.89      1.00      0.94         8
#            9       0.55      0.75      0.63         8
#           10       0.70      0.88      0.78         8
#           11       0.73      1.00      0.84         8
#           12       1.00      1.00      1.00         8
#           13       1.00      0.75      0.86         8
#           14       1.00      1.00      1.00         8
#           15       0.71      0.62      0.67         8
#           16       1.00      1.00      1.00         8
#           17       0.00      0.00      0.00         8
#           18       0.33      0.38      0.35         8
#           19       0.89      1.00      0.94         8
#           20       0.86      0.75      0.80         8
#           21       0.73      1.00      0.84         8
#           22       1.00      0.12      0.22         8
#           23       0.73      1.00      0.84         8
#           24       1.00      0.75      0.86         8
#           25       1.00      1.00      1.00         8
#           26       0.62      0.62      0.62         8
#           27       0.45      0.62      0.53         8
#           28       0.62      1.00      0.76         8
#           29       0.89      1.00      0.94         8
#           30       1.00      0.88      0.93         8
#           31       0.67      1.00      0.80         8
#           32       1.00      1.00      1.00         8
#           33       1.00      0.88      0.93         8
#           34       1.00      0.12      0.22         8
#           35       1.00      0.38      0.55         8
#           36       0.70      0.88      0.78         8
#           37       1.00      0.50      0.67         4
#           38       1.00      0.50      0.67         8
#           39       0.44      0.88      0.58         8
#           40       1.00      0.75      0.86         8
#           41       1.00      0.38      0.55         8
#           42       0.56      0.62      0.59         8
#           43       1.00      1.00      1.00         8
#           44       0.75      0.38      0.50         8
#           45       0.75      0.50      0.60         6
#           46       1.00      1.00      1.00         8
#           47       1.00      0.88      0.93         8
#           48       0.75      0.75      0.75         8
#           49       1.00      0.62      0.77         8
#           50       0.55      0.75      0.63         8
#           51       0.83      0.62      0.71         8
#           52       0.54      0.88      0.67         8
#           53       1.00      1.00      1.00         8
#           54       0.45      0.71      0.56         7
#           55       0.57      0.50      0.53         8
#           56       0.62      1.00      0.76         8
#           57       1.00      1.00      1.00         8
#           58       1.00      0.50      0.67         8
#           59       0.70      0.88      0.78         8
#           60       0.89      1.00      0.94         8
#           61       0.88      0.88      0.88         8
#           62       1.00      0.75      0.86         4
#           63       0.73      1.00      0.84         8
#           64       1.00      1.00      1.00         8
#           65       1.00      0.88      0.93         8
#           66       0.67      1.00      0.80         8
#           67       0.40      1.00      0.57         8
#           68       1.00      0.75      0.86         8
#           69       0.73      1.00      0.84         8
#           70       1.00      0.50      0.67         8
#           71       1.00      1.00      1.00         8
#           72       1.00      1.00      1.00         8
#           73       0.75      0.75      0.75         8
#           74       0.86      0.75      0.80         8
#           75       0.00      0.00      0.00         6
#           76       0.88      0.88      0.88         8
#           77       1.00      0.88      0.93         8
#           78       0.00      0.00      0.00         8
#           79       0.83      0.62      0.71         8
#           80       1.00      0.88      0.93         8
#           81       0.62      1.00      0.76         8
#           82       0.75      0.75      0.75         8
#           83       0.89      1.00      0.94         8
#           84       0.57      1.00      0.73         8
#           85       0.88      0.88      0.88         8
#           86       0.88      0.88      0.88         8
#           87       0.00      0.00      0.00         8
#           88       0.86      0.75      0.80         8
#           89       0.43      0.38      0.40         8
#           90       1.00      1.00      1.00         8
#           91       0.88      0.88      0.88         8
#           92       0.80      1.00      0.89         8
#           93       1.00      0.88      0.93         8
#           94       0.20      0.12      0.15         8
#           95       0.67      0.75      0.71         8
#           96       0.58      0.88      0.70         8
#           97       1.00      0.50      0.67         2
#           98       0.80      1.00      0.89         8
#           99       0.43      0.50      0.46         6
#          100       0.89      1.00      0.94         8
#
#     accuracy                           0.76       783
#    macro avg       0.77      0.75      0.74       783
# weighted avg       0.77      0.76      0.74       783

# %%
# Train late fusion model
print("Training Late Fusion Model:")
train_late_fusion(train_loader, test_loader, text_input_size, image_input_size, output_size, num_epochs=2, multilabel=multilabel, report=True)
# Out:
# Training Late Fusion Model:
# Model Memory Usage: 1.24 MB
# Single Batch Memory Usage: 1.21 MB
# The number of parameters of the model are: 324709
# STAGE:2024-02-01 14:47:40 1413:1413 ActivityProfilerController.cpp:312] Completed Stage: Warm Up
# Epoch 1/2 - Test Accuracy: 0.6692
# Epoch 1/2 - Training Time: 0.42 seconds | Inference Time: 0.13 seconds
# Epoch 2/2 - Test Accuracy: 0.7778
# Epoch 2/2 - Training Time: 0.42 seconds | Inference Time: 0.13 seconds
# STAGE:2024-02-01 14:47:42 1413:1413 ActivityProfilerController.cpp:318] Completed Stage: Collection
# STAGE:2024-02-01 14:47:42 1413:1413 ActivityProfilerController.cpp:322] Completed Stage: Post Processing
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg       CPU Mem  Self CPU Mem    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                          training_batch         9.94%      94.249ms        59.26%     561.984ms       4.194ms    -153.60 Mb    -162.64 Mb           134
# enumerate(DataLoader)#_MultiProcessingDataLoaderIter...        40.31%     382.277ms        40.66%     385.576ms       2.794ms     158.74 Mb     158.69 Mb           138
#                               Optimizer.step#AdamW.step         6.30%      59.699ms        21.64%     205.170ms       1.900ms       2.48 Mb    -262.75 Mb           108
#                                    DataParallel.forward         3.64%      34.536ms        14.41%     136.693ms       1.020ms      16.65 Mb     -10.07 Mb           134
#     autograd::engine::evaluate_function: AddmmBackward0         0.34%       3.187ms         7.02%      66.610ms     205.586us     127.71 Mb      -9.19 Mb           324
#                                            aten::linear         0.19%       1.838ms         6.76%      64.138ms     159.547us       7.32 Mb     167.50 Kb           402
#                                          AddmmBackward0         0.24%       2.243ms         6.36%      60.303ms     186.120us     136.91 Mb           0 b           324
#                                             aten::addmm         5.73%      54.296ms         6.16%      58.433ms     145.356us       7.32 Mb       7.32 Mb           402
#                                                aten::mm         5.72%      54.249ms         5.72%      54.249ms     125.576us     136.91 Mb     136.51 Mb           432
#                                               aten::div         3.68%      34.906ms         4.51%      42.782ms      32.884us     133.70 Mb     133.69 Mb          1301
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 948.306ms
#
# Average Training Time per Epoch: 0.42 seconds
# Total Training Time per Epoch: 0.85 seconds
# Average Inference Time per Epoch: 0.13 seconds
# Total Inference Time per Epoch: 0.26 seconds
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75         8
#            1       1.00      0.88      0.93         8
#            2       0.67      1.00      0.80         8
#            3       0.75      0.60      0.67         5
#            4       0.50      0.50      0.50         8
#            5       1.00      0.14      0.25         7
#            6       0.70      0.88      0.78         8
#            7       1.00      1.00      1.00         8
#            8       1.00      1.00      1.00         8
#            9       0.75      0.38      0.50         8
#           10       0.62      1.00      0.76         8
#           11       0.80      1.00      0.89         8
#           12       1.00      1.00      1.00         8
#           13       1.00      0.62      0.77         8
#           14       0.86      0.75      0.80         8
#           15       0.71      0.62      0.67         8
#           16       1.00      0.75      0.86         8
#           17       1.00      0.12      0.22         8
#           18       0.67      0.50      0.57         8
#           19       0.88      0.88      0.88         8
#           20       1.00      1.00      1.00         8
#           21       0.89      1.00      0.94         8
#           22       0.64      0.88      0.74         8
#           23       0.73      1.00      0.84         8
#           24       1.00      0.75      0.86         8
#           25       0.89      1.00      0.94         8
#           26       0.86      0.75      0.80         8
#           27       0.86      0.75      0.80         8
#           28       0.67      1.00      0.80         8
#           29       0.80      1.00      0.89         8
#           30       0.83      0.62      0.71         8
#           31       0.73      1.00      0.84         8
#           32       1.00      1.00      1.00         8
#           33       1.00      0.88      0.93         8
#           34       0.50      0.12      0.20         8
#           35       0.75      0.38      0.50         8
#           36       0.50      0.88      0.64         8
#           37       1.00      0.25      0.40         4
#           38       0.71      0.62      0.67         8
#           39       0.54      0.88      0.67         8
#           40       1.00      0.88      0.93         8
#           41       1.00      0.25      0.40         8
#           42       0.50      0.62      0.56         8
#           43       0.89      1.00      0.94         8
#           44       0.83      0.62      0.71         8
#           45       1.00      0.50      0.67         6
#           46       0.89      1.00      0.94         8
#           47       0.86      0.75      0.80         8
#           48       0.86      0.75      0.80         8
#           49       0.75      0.38      0.50         8
#           50       0.71      0.62      0.67         8
#           51       0.67      1.00      0.80         8
#           52       0.50      1.00      0.67         8
#           53       0.73      1.00      0.84         8
#           54       0.44      1.00      0.61         7
#           55       1.00      0.25      0.40         8
#           56       0.53      1.00      0.70         8
#           57       1.00      1.00      1.00         8
#           58       1.00      0.88      0.93         8
#           59       0.80      1.00      0.89         8
#           60       1.00      1.00      1.00         8
#           61       0.88      0.88      0.88         8
#           62       1.00      0.50      0.67         4
#           63       0.73      1.00      0.84         8
#           64       1.00      1.00      1.00         8
#           65       0.86      0.75      0.80         8
#           66       0.73      1.00      0.84         8
#           67       0.73      1.00      0.84         8
#           68       1.00      0.75      0.86         8
#           69       0.80      1.00      0.89         8
#           70       0.86      0.75      0.80         8
#           71       0.89      1.00      0.94         8
#           72       0.89      1.00      0.94         8
#           73       0.75      0.75      0.75         8
#           74       0.70      0.88      0.78         8
#           75       0.00      0.00      0.00         6
#           76       1.00      0.75      0.86         8
#           77       0.73      1.00      0.84         8
#           78       0.60      0.38      0.46         8
#           79       0.80      0.50      0.62         8
#           80       0.58      0.88      0.70         8
#           81       0.57      1.00      0.73         8
#           82       1.00      0.75      0.86         8
#           83       0.88      0.88      0.88         8
#           84       0.64      0.88      0.74         8
#           85       0.70      0.88      0.78         8
#           86       0.88      0.88      0.88         8
#           87       1.00      0.12      0.22         8
#           88       0.75      0.75      0.75         8
#           89       0.71      0.62      0.67         8
#           90       0.89      1.00      0.94         8
#           91       0.89      1.00      0.94         8
#           92       0.89      1.00      0.94         8
#           93       0.86      0.75      0.80         8
#           94       0.00      0.00      0.00         8
#           95       1.00      0.75      0.86         8
#           96       0.58      0.88      0.70         8
#           97       1.00      0.50      0.67         2
#           98       0.89      1.00      0.94         8
#           99       1.00      0.50      0.67         6
#          100       0.89      1.00      0.94         8
#
#     accuracy                           0.78       783
#    macro avg       0.80      0.77      0.75       783
# weighted avg       0.80      0.78      0.76       783
