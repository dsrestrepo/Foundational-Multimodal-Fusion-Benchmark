# %% [markdown]
# ### SatelliteBench
#
# * [Dataset](https://physionet.org/content/multimodal-satellite-data/1.0.0/)
#
# * [Paper](https://arxiv.org/abs/2401.11114)

# %%
# %cd ..
# Out:
# /home/datascience/Data Fusion

# %% [markdown]
# ### Setup Environment:

# %%
import os
import pandas as pd

from src.classifiers import preprocess_data, process_labels,split_data

from src.classifiers import VQADataset
from torch.utils.data import DataLoader

from src.classifiers_cpu_metrics import calculate_memory

# %%
PATH = 'Embeddings/satellitedata/'
COLUMN = 'embeddings'

# %%
text_path, images_path = os.listdir(PATH)

# %% [markdown]
# ## Get data

# %% [markdown]
# ### Text

# %%
text = pd.read_csv(os.path.join(PATH, text_path))
text
# Out:
#                   image_id                                               text  \
# 0     73001_2016-06-12.jpg  An image from city Ibagué taken in date 2016-0...
# 1     76001_2017-06-11.jpg  An image from city Cali taken in date 2017-06-...
# 2      8001_2018-04-15.jpg  An image from city Barranquilla taken in date ...
# 3     23001_2016-05-08.jpg  An image from city Montería taken in date 2016...
# 4      5001_2017-04-30.jpg  An image from city Medellín taken in date 2017...
# ...                    ...                                                ...
# 1555  50001_2017-03-19.jpg  An image from city Villavicencio taken in date...
# 1556  23001_2017-03-26.jpg  An image from city Montería taken in date 2017...
# 1557   8001_2017-01-22.jpg  An image from city Barranquilla taken in date ...
# 1558  76001_2017-09-10.jpg  An image from city Cali taken in date 2017-09-...
# 1559  54001_2016-09-18.jpg  An image from city Cúcuta taken in date 2016-0...
#
#       Labels  split                                         embeddings  \
# 0          1  train  [-0.09650082141160965, 1.2055244445800781, 2.9...
# 1          1  train  [-0.4522910714149475, 0.30894309282302856, 2.4...
# 2          0  train  [-0.0652422159910202, 1.3169386386871338, 2.93...
# 3          0  train  [0.1556963175535202, 1.530778408050537, 2.4552...
# 4          0  train  [-0.044512730091810226, 1.4423651695251465, 2....
# ...      ...    ...                                                ...
# 1555       0   test  [-0.13832411170005798, 1.8367681503295898, 2.9...
# 1556       0   test  [0.23850595951080322, 1.6161019802093506, 2.43...
# 1557       0   test  [-0.033280204981565475, 1.276212453842163, 2.9...
# 1558       0   test  [-0.37734487652778625, 0.3405585289001465, 2.4...
# 1559       0   test  [0.35179606080055237, 1.0994224548339844, 2.61...
#
#       Labels_3
# 0            2
# 1            1
# 2            0
# 3            1
# 4            0
# ...        ...
# 1555         0
# 1556         0
# 1557         0
# 1558         0
# 1559         0
#
# [1560 rows x 6 columns]

# %% [markdown]
# ### Images

# %%
images = pd.read_csv(os.path.join(PATH, images_path))
images.head()
# Out:
#               ImageName         0         1         2         3         4  \
# 0  54001_2017-09-03.jpg  0.418299  0.947702  0.930388  1.698969  1.807374
# 1   5360_2016-12-25.jpg -1.733152  0.072954  1.217731  3.282928 -0.287547
# 2  54001_2016-05-29.jpg -2.767494 -2.456418 -1.362022  0.398221  0.084387
# 3  23001_2017-06-18.jpg  1.059556 -2.826679  3.481805 -1.756573  1.112543
# 4   8001_2017-10-22.jpg  0.867121 -0.907118  0.126425  2.029071  0.294439
#
#           5         6         7         8  ...       758       759       760  \
# 0 -4.289507  1.434896 -0.381494 -0.494811  ...  0.121961  0.978187  0.832099
# 1 -3.268999  2.195235 -0.195035  1.090694  ...  1.402666  0.294792 -0.431750
# 2 -2.661927 -0.587058 -0.366591  2.110123  ... -2.133517 -1.048133 -2.228444
# 3  0.456796  1.465225 -1.027905  0.381944  ...  0.490742  0.716432 -0.887395
# 4 -3.256753  1.642754 -0.364946  0.308146  ... -0.105881  1.974369 -1.195430
#
#         761       762       763       764       765       766       767
# 0  0.949627  0.148457  2.130906 -0.018057  0.265088 -0.705121 -0.993023
# 1  0.177886 -0.160068 -1.048362 -0.341087 -1.085934 -3.382511  0.131394
# 2 -0.124623  0.926207  0.679562  1.155562 -0.294559 -3.736522  1.592287
# 3  1.397451  1.245598  1.794311 -0.842432 -0.949204  0.723057 -1.643899
# 4  0.320480 -0.870654  0.438181 -0.759199 -0.114644 -0.726150 -2.746522
#
# [5 rows x 769 columns]

# %% [markdown]
# ### Merge and preprocess the datasets

# %%
df = preprocess_data(text, images, "image_id", "ImageName")
df.drop(columns='text', inplace=True)
df.Labels = df.Labels.astype(str)
df.head()
# Out:
#   Labels  split  Labels_3    text_1    text_2    text_3    text_4    text_5  \
# 0      1  train         2 -0.096501  1.205524  2.905390 -2.219429  1.150509
# 1      1  train         1 -0.452291  0.308943  2.466208 -1.508362  1.242943
# 2      0  train         0 -0.065242  1.316939  2.932482 -2.918486  0.728361
# 3      0  train         1  0.155696  1.530778  2.455221 -2.938133  1.358293
# 4      0  train         0 -0.044513  1.442365  2.950566 -2.586152  1.567985
#
#      text_6    text_7  ...  image_758  image_759  image_760  image_761  \
# 0  0.569432 -0.356423  ...   0.034481   2.774758  -2.069296  -2.671446
# 1  0.745052 -0.132537  ...   0.844251   0.817014  -0.025139  -0.881781
# 2  0.059235  0.183577  ...  -0.725195  -1.517719  -0.476940   0.597161
# 3  0.756503 -0.738332  ...   0.490742   0.716432  -0.887395   1.397451
# 4  0.305916 -0.125401  ...  -0.916818  -1.870640  -2.094238  -0.733254
#
#    image_762  image_763  image_764  image_765  image_766  image_767
# 0   0.515329  -2.267930   0.718683   0.122811  -4.576390   1.210221
# 1  -1.026639  -3.901793   0.602378  -1.098464  -2.236027  -0.790404
# 2  -0.629077  -0.853710  -0.132599   1.200893  -2.902938   0.482014
# 3   1.245598   1.794311  -0.842432  -0.949204   0.723057  -1.643899
# 4   0.511989  -0.297835   0.168513  -0.451834  -3.857307   1.022027
#
# [5 rows x 4867 columns]

# %% [markdown]
# ## Data Perparation

# %%
# Split the data
train_df, test_df = split_data(df)

# Select features and labels vectors
text_columns = [column for column in df.columns if 'text' in column] #[f'text_{i}']
image_columns = [column for column in df.columns if 'image' in column] #[f'image_{i}']
label_columns = 'Labels'


# Process and one-hot encode labels for training set
train_labels, mlb, train_columns = process_labels(train_df, col=label_columns)
test_labels = process_labels(test_df, col=label_columns, train_columns=train_columns)


train_dataset = VQADataset(train_df, text_columns, image_columns, label_columns, mlb, train_columns)
test_dataset = VQADataset(test_df, text_columns, image_columns, label_columns, mlb, train_columns)


train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=2)
# Out:
# Train Shape: (936, 4867)
# Test Shape: (312, 4867)

# %% [markdown]
# ### Models

# %%
text_input_size = len(text_columns)
image_input_size = len(image_columns)
if label_columns == 'DR_2':
    output_size = 1
else:
    output_size = len(pd.unique(train_df[label_columns]))
multilabel = False

# %%
calculate_memory(train_loader, test_loader, text_input_size, image_input_size, output_size)
# Out:
# Early fusion:
# Average Memory per Batch in Train: 1.16 MB
# Total Memory Usage per Epoch Train: 17.37 MB (excluding model parameters)
# Test:
# Average Memory per Batch in Test: 0.39 MB
# Total Memory Usage per Epoch Test: 1.93 MB (excluding model parameters)
# Model:
# Model Memory Usage: 2.38 MB
#
# Late fusion:
# Average Memory per Batch in Train: 1.16 MB
# Total Memory Usage per Epoch Train: 17.37 MB (excluding model parameters)
# Test:
# Average Memory per Batch in Test: 0.39 MB
# Total Memory Usage per Epoch Test: 1.93 MB (excluding model parameters)
# Model:
# Model Memory Usage: 1.19 MB
