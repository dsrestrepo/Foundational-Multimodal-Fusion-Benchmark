# %% [markdown]
# ### HAM 10000
#
# * [Dataset](https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/DBW86T)
#
# * [Original Paper](https://www.nature.com/articles/sdata2018161)

# %% [markdown]
# ### Setup Environment:

# %%
import os
import pandas as pd

from src.classifiers import preprocess_data, process_labels,split_data

from src.classifiers import VQADataset
from torch.utils.data import DataLoader

from src.classifiers_cpu_metrics import train_early_fusion, train_late_fusion

# %%
PATH = 'Embeddings_vlm/ham10000/'
FILE = 'embeddings_blip2.csv'

FILE_PATH = os.path.join(PATH, FILE)

# %% [markdown]
# ## Get data

# %%
df = pd.read_csv(FILE_PATH)
df.drop(columns=['text', 'image_id'], inplace=True)
df.head()
# Out:
#       dx  split  embedding_0  embedding_1  embedding_2  embedding_3  \
# 0     nv  train     0.759658     0.084523     0.560391     0.990704
# 1     nv  train     0.697207     0.134252     0.458888     1.006678
# 2  akiec  train     0.836267     0.043163     0.511651     0.971320
# 3     nv  train     0.678191     0.145648     0.455615     0.998040
# 4     nv  train     0.693284     0.143305     0.460992     1.000840
#
#    embedding_4  embedding_5  embedding_6  embedding_7  ...  embedding_758  \
# 0     1.052331     0.932409    -0.084754    -0.016514  ...       0.430466
# 1     1.280846     0.977329     0.049186    -0.063246  ...       0.608206
# 2     1.040006     1.076945    -0.150755     0.060010  ...       0.307063
# 3     1.313662     0.975402     0.081461    -0.068398  ...       0.643633
# 4     1.279070     0.971170     0.054820    -0.066796  ...       0.609861
#
#    embedding_759  embedding_760  embedding_761  embedding_762  embedding_763  \
# 0      -0.457770       0.773090       0.097314       0.153077      -0.453390
# 1      -0.516563       0.737770       0.038021       0.078190      -0.295397
# 2      -0.370468       0.753393       0.051292       0.351723      -0.511813
# 3      -0.528829       0.726183       0.029208       0.047751      -0.271805
# 4      -0.515142       0.734393       0.038820       0.076379      -0.296665
#
#    embedding_764  embedding_765  embedding_766  embedding_767
# 0      -0.412429      -1.477566      -0.092627      -0.361740
# 1      -0.340849      -1.447219      -0.143768      -0.503913
# 2      -0.415974      -1.475609      -0.083345      -0.331805
# 3      -0.318904      -1.438784      -0.149104      -0.512778
# 4      -0.327435      -1.449966      -0.147958      -0.507480
#
# [5 rows x 770 columns]

# %% [markdown]
# ## Data Perparation

# %%
# Split the data
train_df, test_df = split_data(df)

# Select features and labels vectors. 
# In this case, since we just have multimodal embeddings instead of unimodal embeddings,
# We'll split the column into half and half so we can use the same code.
# Identify columns with "embedding_" in their names
embedding_columns = [column for column in df.columns if 'embedding_' in column]

# Split the embedding columns evenly between text and image columns
num_embeddings = len(embedding_columns)
half_num_embeddings = num_embeddings // 2

text_columns = embedding_columns[:half_num_embeddings]
image_columns = embedding_columns[half_num_embeddings:]

label_columns = 'dx'


# Process and one-hot encode labels for training set
train_labels, mlb, train_columns = process_labels(train_df, col=label_columns)
test_labels = process_labels(test_df, col=label_columns, train_columns=train_columns)


train_dataset = VQADataset(train_df, text_columns, image_columns, label_columns, mlb, train_columns)
test_dataset = VQADataset(test_df, text_columns, image_columns, label_columns, mlb, train_columns)


train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=2)
# Out:
# Train Shape: (8012, 770)
# Test Shape: (2003, 770)

# %% [markdown]
# ### Models

# %%
text_input_size = len(text_columns)
image_input_size = len(image_columns)
if label_columns == 'DR_2':
    output_size = 1
else:
    output_size = len(pd.unique(train_df[label_columns]))
multilabel = False

# %%
# Train early fusion model
print("Training Early Fusion Model:")
train_early_fusion(train_loader, test_loader, text_input_size, image_input_size, output_size, num_epochs=15, multilabel=multilabel, report=True)
# Out:
# Training Early Fusion Model:
# Model Memory Usage: 0.38 MB
# The number of parameters of the model are: 99591
# STAGE:2024-02-07 19:26:36 16946:16946 ActivityProfilerController.cpp:312] Completed Stage: Warm Up
# Epoch 1/15 - Test Accuracy: 0.0654
# Epoch 1/15 - Training Time: 0.56 seconds | Inference Time: 0.15 seconds
# Epoch 2/15 - Test Accuracy: 0.0714
# Epoch 2/15 - Training Time: 0.57 seconds | Inference Time: 0.17 seconds
# Epoch 3/15 - Test Accuracy: 0.0799
# Epoch 3/15 - Training Time: 0.55 seconds | Inference Time: 0.17 seconds
# Epoch 4/15 - Test Accuracy: 0.4453
# Epoch 4/15 - Training Time: 0.62 seconds | Inference Time: 0.17 seconds
# Epoch 5/15 - Test Accuracy: 0.0734
# Epoch 5/15 - Training Time: 0.58 seconds | Inference Time: 0.18 seconds
# Epoch 6/15 - Test Accuracy: 0.0639
# Epoch 6/15 - Training Time: 0.58 seconds | Inference Time: 0.19 seconds
# Epoch 7/15 - Test Accuracy: 0.0939
# Epoch 7/15 - Training Time: 0.65 seconds | Inference Time: 0.18 seconds
# Epoch 8/15 - Test Accuracy: 0.0499
# Epoch 8/15 - Training Time: 0.58 seconds | Inference Time: 0.19 seconds
# Epoch 9/15 - Test Accuracy: 0.0889
# Epoch 9/15 - Training Time: 0.65 seconds | Inference Time: 0.17 seconds
# Epoch 10/15 - Test Accuracy: 0.0769
# Epoch 10/15 - Training Time: 0.61 seconds | Inference Time: 0.20 seconds
# Epoch 11/15 - Test Accuracy: 0.4294
# Epoch 11/15 - Training Time: 0.67 seconds | Inference Time: 0.19 seconds
# Epoch 12/15 - Test Accuracy: 0.0749
# Epoch 12/15 - Training Time: 0.61 seconds | Inference Time: 0.19 seconds
# Epoch 13/15 - Test Accuracy: 0.3674
# Epoch 13/15 - Training Time: 0.75 seconds | Inference Time: 0.16 seconds
# Epoch 14/15 - Test Accuracy: 0.1368
# Epoch 14/15 - Training Time: 0.58 seconds | Inference Time: 0.20 seconds
# Epoch 15/15 - Test Accuracy: 0.1288
# Epoch 15/15 - Training Time: 0.60 seconds | Inference Time: 0.18 seconds
# STAGE:2024-02-07 19:26:50 16946:16946 ActivityProfilerController.cpp:318] Completed Stage: Collection
# STAGE:2024-02-07 19:26:50 16946:16946 ActivityProfilerController.cpp:322] Completed Stage: Post Processing
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg       CPU Mem  Self CPU Mem    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                          training_batch         9.92%        1.056s        53.07%        5.650s       2.990ms    -354.42 Mb    -362.76 Mb          1890
# enumerate(DataLoader)#_MultiProcessingDataLoaderIter...        39.92%        4.250s        40.54%        4.316s       1.798ms     443.21 Mb     442.29 Mb          2400
#                               Optimizer.step#AdamW.step         7.04%     749.601ms        19.62%        2.089s       1.105ms     778.08 Kb      -1.39 Gb          1890
#                                    DataParallel.forward         3.82%     406.684ms        14.91%        1.587s     669.731us     475.31 Mb    -194.30 Mb          2370
#                                         inference_batch         1.85%     196.946ms         6.35%     675.813ms       1.408ms     -86.92 Mb     -88.56 Mb           480
#     autograd::engine::evaluate_function: AddmmBackward0         0.43%      45.290ms         4.63%     493.014ms     130.427us     302.20 Mb    -471.95 Mb          3780
#                                              aten::mul_         2.92%     311.178ms         4.01%     427.036ms      18.829us       1.77 Kb    -100.86 Kb         22680
#                                          AddmmBackward0         0.30%      32.077ms         3.82%     407.086ms     107.695us     773.89 Mb           0 b          3780
#                                            aten::linear         0.24%      25.359ms         3.66%     389.181ms      82.106us      77.36 Mb     748.25 Kb          4740
#                                        aten::batch_norm         0.05%       5.068ms         3.30%     351.692ms     148.393us      75.20 Mb    -890.50 Kb          2370
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 10.647s
#
# Average Training Time per Epoch: 0.61 seconds
# Total Training Time per Epoch: 9.14 seconds
# Average Inference Time per Epoch: 0.18 seconds
# Total Inference Time per Epoch: 2.68 seconds
#               precision    recall  f1-score   support
#
#            0       0.08      0.34      0.13        65
#            1       0.06      0.79      0.11       103
#            2       0.25      0.01      0.03       220
#            3       0.05      0.04      0.04        23
#            4       0.32      0.15      0.20       223
#            5       0.80      0.09      0.15      1341
#            6       0.10      0.11      0.11        28
#
#     accuracy                           0.13      2003
#    macro avg       0.24      0.22      0.11      2003
# weighted avg       0.61      0.13      0.14      2003
