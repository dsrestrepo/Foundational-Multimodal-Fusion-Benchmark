# %% [markdown]
# ### SatelliteBench
#
# * [Dataset](https://physionet.org/content/multimodal-satellite-data/1.0.0/)
#
# * [Paper](https://arxiv.org/abs/2401.11114)

# %% [markdown]
# ### Setup Environment:

# %%
import os
import pandas as pd

from src.classifiers import preprocess_data, process_labels,split_data

from src.classifiers import VQADataset
from torch.utils.data import DataLoader

from src.classifiers_cpu_metrics import train_early_fusion, train_late_fusion

# %%
PATH = 'Embeddings/satellitedata/'
COLUMN = 'embeddings'

# %%
os.listdir(PATH)
# Out:
# ['text_embeddings.csv', 'Embeddings_dinov2_base.csv']

# %%
text_path, images_path = os.listdir(PATH)

# %% [markdown]
# ## Get data

# %% [markdown]
# ### Text

# %%
text = pd.read_csv(os.path.join(PATH, text_path))
text
# Out:
#                   image_id                                               text  \
# 0     73001_2016-06-12.jpg  An image from city Ibagué taken in date 2016-0...
# 1     76001_2017-06-11.jpg  An image from city Cali taken in date 2017-06-...
# 2      8001_2018-04-15.jpg  An image from city Barranquilla taken in date ...
# 3     23001_2016-05-08.jpg  An image from city Montería taken in date 2016...
# 4      5001_2017-04-30.jpg  An image from city Medellín taken in date 2017...
# ...                    ...                                                ...
# 1555  50001_2017-03-19.jpg  An image from city Villavicencio taken in date...
# 1556  23001_2017-03-26.jpg  An image from city Montería taken in date 2017...
# 1557   8001_2017-01-22.jpg  An image from city Barranquilla taken in date ...
# 1558  76001_2017-09-10.jpg  An image from city Cali taken in date 2017-09-...
# 1559  54001_2016-09-18.jpg  An image from city Cúcuta taken in date 2016-0...
#
#       Labels  split                                         embeddings  \
# 0          2  train  [-0.09650082141160965, 1.2055244445800781, 2.9...
# 1          1  train  [-0.4522910714149475, 0.30894309282302856, 2.4...
# 2          0  train  [-0.0652422159910202, 1.3169386386871338, 2.93...
# 3          1  train  [0.1556963175535202, 1.530778408050537, 2.4552...
# 4          0  train  [-0.044512730091810226, 1.4423651695251465, 2....
# ...      ...    ...                                                ...
# 1555       0   test  [-0.13832411170005798, 1.8367681503295898, 2.9...
# 1556       0   test  [0.23850595951080322, 1.6161019802093506, 2.43...
# 1557       0   test  [-0.033280204981565475, 1.276212453842163, 2.9...
# 1558       0   test  [-0.37734487652778625, 0.3405585289001465, 2.4...
# 1559       0   test  [0.35179606080055237, 1.0994224548339844, 2.61...
#
#       Labels_4
# 0            3
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# 1555         1
# 1556         0
# 1557         0
# 1558         0
# 1559         1
#
# [1560 rows x 6 columns]

# %% [markdown]
# ### Images

# %%
images = pd.read_csv(os.path.join(PATH, images_path))
images.head()
# Out:
#               ImageName         0         1         2         3         4  \
# 0  54001_2017-09-03.jpg  0.418299  0.947702  0.930388  1.698969  1.807374
# 1   5360_2016-12-25.jpg -1.733152  0.072954  1.217731  3.282928 -0.287547
# 2  54001_2016-05-29.jpg -2.767494 -2.456418 -1.362022  0.398221  0.084387
# 3  23001_2017-06-18.jpg  1.059556 -2.826679  3.481805 -1.756573  1.112543
# 4   8001_2017-10-22.jpg  0.867121 -0.907118  0.126425  2.029071  0.294439
#
#           5         6         7         8  ...       758       759       760  \
# 0 -4.289507  1.434896 -0.381494 -0.494811  ...  0.121961  0.978187  0.832099
# 1 -3.268999  2.195235 -0.195035  1.090694  ...  1.402666  0.294792 -0.431750
# 2 -2.661927 -0.587058 -0.366591  2.110123  ... -2.133517 -1.048133 -2.228444
# 3  0.456796  1.465225 -1.027905  0.381944  ...  0.490742  0.716432 -0.887395
# 4 -3.256753  1.642754 -0.364946  0.308146  ... -0.105881  1.974369 -1.195430
#
#         761       762       763       764       765       766       767
# 0  0.949627  0.148457  2.130906 -0.018057  0.265088 -0.705121 -0.993023
# 1  0.177886 -0.160068 -1.048362 -0.341087 -1.085934 -3.382511  0.131394
# 2 -0.124623  0.926207  0.679562  1.155562 -0.294559 -3.736522  1.592287
# 3  1.397451  1.245598  1.794311 -0.842432 -0.949204  0.723057 -1.643899
# 4  0.320480 -0.870654  0.438181 -0.759199 -0.114644 -0.726150 -2.746522
#
# [5 rows x 769 columns]

# %% [markdown]
# ### Merge and preprocess the datasets

# %%
df = preprocess_data(text, images, "image_id", "ImageName")
df.drop(columns='text', inplace=True)
df.Labels = df.Labels.astype(str)
df.head()
# Out:
#   Labels  split  Labels_4    text_1    text_2    text_3    text_4    text_5  \
# 0      2  train         3 -0.096501  1.205524  2.905390 -2.219429  1.150509
# 1      1  train         1 -0.452291  0.308943  2.466208 -1.508362  1.242943
# 2      0  train         1 -0.065242  1.316939  2.932482 -2.918486  0.728361
# 3      1  train         1  0.155696  1.530778  2.455221 -2.938133  1.358293
# 4      0  train         1 -0.044513  1.442365  2.950566 -2.586152  1.567985
#
#      text_6    text_7  ...  image_758  image_759  image_760  image_761  \
# 0  0.569432 -0.356423  ...   0.034481   2.774758  -2.069296  -2.671446
# 1  0.745052 -0.132537  ...   0.844251   0.817014  -0.025139  -0.881781
# 2  0.059235  0.183577  ...  -0.725195  -1.517719  -0.476940   0.597161
# 3  0.756503 -0.738332  ...   0.490742   0.716432  -0.887395   1.397451
# 4  0.305916 -0.125401  ...  -0.916818  -1.870640  -2.094238  -0.733254
#
#    image_762  image_763  image_764  image_765  image_766  image_767
# 0   0.515329  -2.267930   0.718683   0.122811  -4.576390   1.210221
# 1  -1.026639  -3.901793   0.602378  -1.098464  -2.236027  -0.790404
# 2  -0.629077  -0.853710  -0.132599   1.200893  -2.902938   0.482014
# 3   1.245598   1.794311  -0.842432  -0.949204   0.723057  -1.643899
# 4   0.511989  -0.297835   0.168513  -0.451834  -3.857307   1.022027
#
# [5 rows x 4867 columns]

# %% [markdown]
# ## Data Perparation

# %%
# Split the data
train_df, test_df = split_data(df)

# Select features and labels vectors
text_columns = [column for column in df.columns if 'text' in column] #[f'text_{i}']
image_columns = [column for column in df.columns if 'image' in column] #[f'image_{i}']
label_columns = 'Labels'


# Process and one-hot encode labels for training set
train_labels, mlb, train_columns = process_labels(train_df, col=label_columns)
test_labels = process_labels(test_df, col=label_columns, train_columns=train_columns)


train_dataset = VQADataset(train_df, text_columns, image_columns, label_columns, mlb, train_columns)
test_dataset = VQADataset(test_df, text_columns, image_columns, label_columns, mlb, train_columns)


train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=2)
# Out:
# Train Shape: (936, 4867)
# Test Shape: (312, 4867)

# %% [markdown]
# ### Models

# %%
text_input_size = len(text_columns)
image_input_size = len(image_columns)
if label_columns == 'DR_2':
    output_size = 1
else:
    output_size = len(pd.unique(train_df[label_columns]))
multilabel = False

# %%
# Train early fusion model
print("Training Early Fusion Model:")
train_early_fusion(train_loader, test_loader, text_input_size, image_input_size, output_size, num_epochs=30, multilabel=multilabel, report=True)
# Out:
# Training Early Fusion Model:
# Model Memory Usage: 2.38 MB
# The number of parameters of the model are: 623363
# STAGE:2024-02-08 20:26:14 29752:29752 ActivityProfilerController.cpp:312] Completed Stage: Warm Up
# Epoch 1/30 - Test Accuracy: 0.2276, macro-f1: 0.1965
# Epoch 1/30 - Training Time: 0.27 seconds | Inference Time: 0.12 seconds
# Epoch 2/30 - Test Accuracy: 0.3237, macro-f1: 0.2363
# Epoch 2/30 - Training Time: 0.33 seconds | Inference Time: 0.11 seconds
# Epoch 3/30 - Test Accuracy: 0.3429, macro-f1: 0.3245
# Epoch 3/30 - Training Time: 0.35 seconds | Inference Time: 0.12 seconds
# Epoch 4/30 - Test Accuracy: 0.4103, macro-f1: 0.3710
# Epoch 4/30 - Training Time: 0.33 seconds | Inference Time: 0.12 seconds
# Epoch 5/30 - Test Accuracy: 0.4776, macro-f1: 0.3978
# Epoch 5/30 - Training Time: 0.29 seconds | Inference Time: 0.12 seconds
# Epoch 6/30 - Test Accuracy: 0.4135, macro-f1: 0.3600
# Epoch 6/30 - Training Time: 0.37 seconds | Inference Time: 0.12 seconds
# Epoch 7/30 - Test Accuracy: 0.4071, macro-f1: 0.3577
# Epoch 7/30 - Training Time: 0.37 seconds | Inference Time: 0.12 seconds
# Epoch 8/30 - Test Accuracy: 0.4391, macro-f1: 0.3839
# Epoch 8/30 - Training Time: 0.35 seconds | Inference Time: 0.11 seconds
# Epoch 9/30 - Test Accuracy: 0.4647, macro-f1: 0.4250
# Epoch 9/30 - Training Time: 0.35 seconds | Inference Time: 0.13 seconds
# Epoch 10/30 - Test Accuracy: 0.4679, macro-f1: 0.4376
# Epoch 10/30 - Training Time: 0.30 seconds | Inference Time: 0.12 seconds
# Epoch 11/30 - Test Accuracy: 0.4231, macro-f1: 0.3901
# Epoch 11/30 - Training Time: 0.31 seconds | Inference Time: 0.13 seconds
# Epoch 12/30 - Test Accuracy: 0.4583, macro-f1: 0.4197
# Epoch 12/30 - Training Time: 0.37 seconds | Inference Time: 0.13 seconds
# Epoch 13/30 - Test Accuracy: 0.4263, macro-f1: 0.4086
# Epoch 13/30 - Training Time: 0.31 seconds | Inference Time: 0.13 seconds
# Epoch 14/30 - Test Accuracy: 0.3590, macro-f1: 0.3474
# Epoch 14/30 - Training Time: 0.36 seconds | Inference Time: 0.12 seconds
# Epoch 15/30 - Test Accuracy: 0.4103, macro-f1: 0.3713
# Epoch 15/30 - Training Time: 0.32 seconds | Inference Time: 0.11 seconds
# Epoch 16/30 - Test Accuracy: 0.4391, macro-f1: 0.4205
# Epoch 16/30 - Training Time: 0.31 seconds | Inference Time: 0.12 seconds
# Epoch 17/30 - Test Accuracy: 0.4263, macro-f1: 0.3865
# Epoch 17/30 - Training Time: 0.32 seconds | Inference Time: 0.11 seconds
# Epoch 18/30 - Test Accuracy: 0.4904, macro-f1: 0.4478
# Epoch 18/30 - Training Time: 0.32 seconds | Inference Time: 0.12 seconds
# Epoch 19/30 - Test Accuracy: 0.4615, macro-f1: 0.4476
# Epoch 19/30 - Training Time: 0.32 seconds | Inference Time: 0.13 seconds
# Epoch 20/30 - Test Accuracy: 0.4551, macro-f1: 0.4352
# Epoch 20/30 - Training Time: 0.37 seconds | Inference Time: 0.12 seconds
# Epoch 21/30 - Test Accuracy: 0.4231, macro-f1: 0.3900
# Epoch 21/30 - Training Time: 0.35 seconds | Inference Time: 0.13 seconds
# Epoch 22/30 - Test Accuracy: 0.5321, macro-f1: 0.3988
# Epoch 22/30 - Training Time: 0.34 seconds | Inference Time: 0.12 seconds
# Epoch 23/30 - Test Accuracy: 0.3301, macro-f1: 0.3307
# Epoch 23/30 - Training Time: 0.36 seconds | Inference Time: 0.12 seconds
# Epoch 24/30 - Test Accuracy: 0.5353, macro-f1: 0.4931
# Epoch 24/30 - Training Time: 0.35 seconds | Inference Time: 0.13 seconds
# Epoch 25/30 - Test Accuracy: 0.3782, macro-f1: 0.3689
# Epoch 25/30 - Training Time: 0.34 seconds | Inference Time: 0.12 seconds
# Epoch 26/30 - Test Accuracy: 0.3750, macro-f1: 0.3771
# Epoch 26/30 - Training Time: 0.35 seconds | Inference Time: 0.13 seconds
# Epoch 27/30 - Test Accuracy: 0.3718, macro-f1: 0.3226
# Epoch 27/30 - Training Time: 0.34 seconds | Inference Time: 0.12 seconds
# Epoch 28/30 - Test Accuracy: 0.4968, macro-f1: 0.4633
# Epoch 28/30 - Training Time: 0.39 seconds | Inference Time: 0.11 seconds
# Epoch 29/30 - Test Accuracy: 0.3654, macro-f1: 0.3541
# Epoch 29/30 - Training Time: 0.33 seconds | Inference Time: 0.12 seconds
# Epoch 30/30 - Test Accuracy: 0.3910, macro-f1: 0.3684
# Epoch 30/30 - Training Time: 0.36 seconds | Inference Time: 0.13 seconds
# STAGE:2024-02-08 20:26:29 29752:29752 ActivityProfilerController.cpp:318] Completed Stage: Collection
# STAGE:2024-02-08 20:26:29 29752:29752 ActivityProfilerController.cpp:322] Completed Stage: Post Processing
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg       CPU Mem  Self CPU Mem    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                          training_batch         5.91%     667.946ms        57.38%        6.489s       7.210ms    -522.67 Mb    -530.74 Mb           900
# enumerate(DataLoader)#_MultiProcessingDataLoaderIter...        36.96%        4.179s        37.29%        4.217s       3.347ms     694.90 Mb     694.69 Mb          1260
#                               Optimizer.step#AdamW.step         3.90%     441.236ms        23.41%        2.647s       2.941ms       4.76 Mb      -4.16 Gb           900
#                                    DataParallel.forward         3.17%     358.532ms        16.32%        1.845s       1.538ms     549.74 Mb    -201.46 Mb          1200
#     autograd::engine::evaluate_function: AddmmBackward0         0.29%      32.587ms        11.48%        1.298s     721.069us       1.57 Gb    -548.62 Mb          1800
#                                          AddmmBackward0         0.15%      16.630ms        11.00%        1.244s     691.336us       2.10 Gb           0 b          1800
#                                                aten::mm        10.62%        1.201s        10.62%        1.201s     444.941us       2.10 Gb       2.10 Gb          2700
#                                              aten::mul_         7.78%     879.882ms         8.32%     941.387ms      87.165us      -2.25 Kb     -50.09 Kb         10800
#                                               aten::cat         6.83%     772.422ms         7.01%     793.043ms     660.869us     694.69 Mb     694.69 Mb          1200
#                                         inference_batch         1.16%     130.707ms         5.23%     590.854ms       1.970ms    -164.66 Mb    -164.88 Mb           300
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 11.308s
#
# Average Training Time per Epoch: 0.34 seconds
# Total Training Time per Epoch: 10.14 seconds
# Average Inference Time per Epoch: 0.12 seconds
# Total Inference Time per Epoch: 3.63 seconds
#               precision    recall  f1-score   support
#
#            0       0.65      0.34      0.44       154
#            1       0.22      0.24      0.23        68
#            2       0.34      0.60      0.44        90
#
#     accuracy                           0.39       312
#    macro avg       0.40      0.39      0.37       312
# weighted avg       0.47      0.39      0.39       312

# %%
# Train late fusion model
print("Training Late Fusion Model:")
train_late_fusion(train_loader, test_loader, text_input_size, image_input_size, output_size, num_epochs=30, multilabel=multilabel, report=True)
# Out:
# Training Late Fusion Model:
# Model Memory Usage: 1.19 MB
# The number of parameters of the model are: 312067
# STAGE:2024-02-08 20:27:09 29752:29752 ActivityProfilerController.cpp:312] Completed Stage: Warm Up
# Epoch 1/30 - Test Accuracy: 0.3397, macro-f1: 0.3138
# Epoch 1/30 - Training Time: 0.44 seconds | Inference Time: 0.17 seconds
# Epoch 2/30 - Test Accuracy: 0.4006, macro-f1: 0.3740
# Epoch 2/30 - Training Time: 0.42 seconds | Inference Time: 0.17 seconds
# Epoch 3/30 - Test Accuracy: 0.3878, macro-f1: 0.3860
# Epoch 3/30 - Training Time: 0.43 seconds | Inference Time: 0.18 seconds
# Epoch 4/30 - Test Accuracy: 0.4231, macro-f1: 0.4098
# Epoch 4/30 - Training Time: 0.46 seconds | Inference Time: 0.18 seconds
# Epoch 5/30 - Test Accuracy: 0.3942, macro-f1: 0.3833
# Epoch 5/30 - Training Time: 0.48 seconds | Inference Time: 0.18 seconds
# Epoch 6/30 - Test Accuracy: 0.4263, macro-f1: 0.4035
# Epoch 6/30 - Training Time: 0.44 seconds | Inference Time: 0.18 seconds
# Epoch 7/30 - Test Accuracy: 0.4263, macro-f1: 0.3804
# Epoch 7/30 - Training Time: 0.46 seconds | Inference Time: 0.19 seconds
# Epoch 8/30 - Test Accuracy: 0.4872, macro-f1: 0.4481
# Epoch 8/30 - Training Time: 0.43 seconds | Inference Time: 0.19 seconds
# Epoch 9/30 - Test Accuracy: 0.4167, macro-f1: 0.3853
# Epoch 9/30 - Training Time: 0.41 seconds | Inference Time: 0.17 seconds
# Epoch 10/30 - Test Accuracy: 0.4808, macro-f1: 0.4581
# Epoch 10/30 - Training Time: 0.54 seconds | Inference Time: 0.17 seconds
# Epoch 11/30 - Test Accuracy: 0.4359, macro-f1: 0.3998
# Epoch 11/30 - Training Time: 0.43 seconds | Inference Time: 0.19 seconds
# Epoch 12/30 - Test Accuracy: 0.4904, macro-f1: 0.4309
# Epoch 12/30 - Training Time: 0.43 seconds | Inference Time: 0.16 seconds
# Epoch 13/30 - Test Accuracy: 0.4776, macro-f1: 0.4532
# Epoch 13/30 - Training Time: 0.42 seconds | Inference Time: 0.18 seconds
# Epoch 14/30 - Test Accuracy: 0.4135, macro-f1: 0.3995
# Epoch 14/30 - Training Time: 0.43 seconds | Inference Time: 0.18 seconds
# Epoch 15/30 - Test Accuracy: 0.5256, macro-f1: 0.4751
# Epoch 15/30 - Training Time: 0.42 seconds | Inference Time: 0.18 seconds
# Epoch 16/30 - Test Accuracy: 0.4647, macro-f1: 0.4591
# Epoch 16/30 - Training Time: 0.43 seconds | Inference Time: 0.19 seconds
# Epoch 17/30 - Test Accuracy: 0.5064, macro-f1: 0.4646
# Epoch 17/30 - Training Time: 0.41 seconds | Inference Time: 0.18 seconds
# Epoch 18/30 - Test Accuracy: 0.4199, macro-f1: 0.4120
# Epoch 18/30 - Training Time: 0.42 seconds | Inference Time: 0.18 seconds
# Epoch 19/30 - Test Accuracy: 0.4679, macro-f1: 0.4317
# Epoch 19/30 - Training Time: 0.53 seconds | Inference Time: 0.18 seconds
# Epoch 20/30 - Test Accuracy: 0.4423, macro-f1: 0.4228
# Epoch 20/30 - Training Time: 0.45 seconds | Inference Time: 0.18 seconds
# Epoch 21/30 - Test Accuracy: 0.4519, macro-f1: 0.4345
# Epoch 21/30 - Training Time: 0.47 seconds | Inference Time: 0.20 seconds
# Epoch 22/30 - Test Accuracy: 0.3526, macro-f1: 0.3017
# Epoch 22/30 - Training Time: 0.44 seconds | Inference Time: 0.19 seconds
# Epoch 23/30 - Test Accuracy: 0.4295, macro-f1: 0.4317
# Epoch 23/30 - Training Time: 0.44 seconds | Inference Time: 0.18 seconds
# Epoch 24/30 - Test Accuracy: 0.4487, macro-f1: 0.4382
# Epoch 24/30 - Training Time: 0.55 seconds | Inference Time: 0.17 seconds
# Epoch 25/30 - Test Accuracy: 0.4006, macro-f1: 0.3777
# Epoch 25/30 - Training Time: 0.45 seconds | Inference Time: 0.19 seconds
# Epoch 26/30 - Test Accuracy: 0.4968, macro-f1: 0.4809
# Epoch 26/30 - Training Time: 0.47 seconds | Inference Time: 0.18 seconds
# Epoch 27/30 - Test Accuracy: 0.5160, macro-f1: 0.4363
# Epoch 27/30 - Training Time: 0.44 seconds | Inference Time: 0.20 seconds
# Epoch 28/30 - Test Accuracy: 0.4904, macro-f1: 0.4865
# Epoch 28/30 - Training Time: 0.42 seconds | Inference Time: 0.18 seconds
# Epoch 29/30 - Test Accuracy: 0.4904, macro-f1: 0.4624
# Epoch 29/30 - Training Time: 0.43 seconds | Inference Time: 0.18 seconds
# Epoch 30/30 - Test Accuracy: 0.4327, macro-f1: 0.3912
# Epoch 30/30 - Training Time: 0.42 seconds | Inference Time: 0.18 seconds
# STAGE:2024-02-08 20:27:29 29752:29752 ActivityProfilerController.cpp:318] Completed Stage: Collection
# STAGE:2024-02-08 20:27:29 29752:29752 ActivityProfilerController.cpp:322] Completed Stage: Post Processing
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg       CPU Mem  Self CPU Mem    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                          training_batch         6.89%     949.921ms        59.59%        8.214s       6.845ms    -690.90 Mb    -695.47 Mb          1200
# enumerate(DataLoader)#_MultiProcessingDataLoaderIter...        39.94%        5.506s        40.33%        5.560s       4.413ms     694.90 Mb     694.69 Mb          1260
#                               Optimizer.step#AdamW.step         4.75%     654.821ms        32.28%        4.450s       4.945ms       2.38 Mb      -2.07 Gb           900
#                                    DataParallel.forward         3.23%     445.162ms        10.61%        1.462s       1.219ms      28.73 Mb     -46.61 Mb          1200
#                                               aten::div         8.11%        1.118s         9.33%        1.286s     118.737us       1.05 Gb       1.05 Gb         10829
#                                              aten::sqrt         7.95%        1.096s         7.95%        1.096s     121.792us       1.05 Gb       1.05 Gb          9000
#                                              aten::mul_         4.93%     679.163ms         5.70%     785.478ms      43.638us      -2.08 Kb     -83.43 Kb         18000
#     autograd::engine::evaluate_function: AddmmBackward0         0.19%      26.709ms         5.13%     706.917ms     261.821us       1.03 Gb     -27.43 Mb          2700
#                                          AddmmBackward0         0.14%      19.783ms         4.74%     653.254ms     241.946us       1.06 Gb           0 b          2700
#                                                aten::mm         4.20%     579.317ms         4.20%     579.344ms     160.929us       1.06 Gb       1.06 Gb          3600
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 13.785s
#
# Average Training Time per Epoch: 0.45 seconds
# Total Training Time per Epoch: 13.38 seconds
# Average Inference Time per Epoch: 0.18 seconds
# Total Inference Time per Epoch: 5.42 seconds
#               precision    recall  f1-score   support
#
#            0       0.65      0.36      0.47       154
#            1       0.26      0.18      0.21        68
#            2       0.37      0.74      0.50        90
#
#     accuracy                           0.43       312
#    macro avg       0.43      0.43      0.39       312
# weighted avg       0.49      0.43      0.42       312
