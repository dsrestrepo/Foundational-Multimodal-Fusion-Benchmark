# %% [markdown]
# ### Setup

# %%
import os
import pandas as pd 
from epiweeks import Week

# %%
PATH_CODES = '../../cities.csv'
KEYWORD = 'Violencia'

# %% [markdown]
# #### CSV Files

# %%
cities = pd.read_csv(PATH_CODES)
cities
# Out:
#        lat      lng   Municipality  Municipality code     ISO
# 0   6.2447 -75.5748       Medellín               5001  CO-ANT
# 1   3.4400 -76.5197           Cali              76001  CO-VAC
# 2   4.5781 -74.2144         Soacha              25754  CO-CUN
# 3   4.1425 -73.6294  Villavicencio              50001  CO-MET
# 4   1.2136 -77.2811          Pasto              52001  CO-NAR
# 5  10.9639 -74.7964   Barranquilla               8001  CO-ATL
# 6   7.1186 -73.1161    Bucaramanga              68001  CO-SAN
# 7   4.4378 -75.2006         Ibagué              73001  CO-TOL
# 8   2.4411 -76.6061        Popayán              19001  CO-CAU
# 9   7.9075 -72.5047         Cúcuta              54001  CO-NSA

# %% [markdown]
# ### Read each file

# %%
dfs = []
for city in cities.ISO:
    
    dfs.append(pd.concat([pd.read_csv(f'cities/{city}_{KEYWORD}(1).csv'), pd.read_csv(f'cities/{city}_{KEYWORD}.csv')]))

# %%
dfs[0]
# Out:
#            Category: All categories
# Week          Violence: (Antioquia)
# 2014-01-05                       35
# 2014-01-12                       44
# 2014-01-19                       46
# 2014-01-26                       41
# ...                             ...
# 2023-07-30                       59
# 2023-08-06                       59
# 2023-08-13                       68
# 2023-08-20                       54
# 2023-08-27                       67
#
# [506 rows x 1 columns]

# %% [markdown]
# ### Merge:

# %%
# Merge the dataframes by the "Week" column
merged_df = pd.concat(dfs, axis=1, keys=cities['Municipality'])

# %%
merged_df
# Out:
# Municipality                 Medellín                         Cali  \
#              Category: All categories     Category: All categories
# Week            Violence: (Antioquia)  Violence: (Valle del Cauca)
# 2014-01-05                         35                           25
# 2014-01-12                         44                           34
# 2014-01-19                         46                           40
# 2014-01-26                         41                           49
# ...                               ...                          ...
# 2023-07-30                         59                           50
# 2023-08-06                         59                           48
# 2023-08-13                         68                           44
# 2023-08-20                         54                           61
# 2023-08-27                         67                           69
#
# Municipality                    Soacha            Villavicencio  \
#               Category: All categories Category: All categories
# Week          Violence: (Cundinamarca)         Violence: (Meta)
# 2014-01-05                          31                       66
# 2014-01-12                          22                       47
# 2014-01-19                           0                        0
# 2014-01-26                         100                        0
# ...                                ...                      ...
# 2023-07-30                          56                       41
# 2023-08-06                          47                       48
# 2023-08-13                          47                       47
# 2023-08-20                          61                       44
# 2023-08-27                          47                       54
#
# Municipality                    Pasto             Barranquilla  \
#              Category: All categories Category: All categories
# Week               Violence: (Narino)    Violence: (Atlantico)
# 2014-01-05                         26                       27
# 2014-01-12                         64                       21
# 2014-01-19                         16                       49
# 2014-01-26                         63                       26
# ...                               ...                      ...
# 2023-07-30                         41                       38
# 2023-08-06                         81                       45
# 2023-08-13                         43                       55
# 2023-08-20                         57                       51
# 2023-08-27                         41                       57
#
# Municipality                       Bucaramanga                   Ibagué  \
#                       Category: All categories Category: All categories
# Week          Violence: (Santander Department)       Violence: (Tolima)
# 2014-01-05                                  23                        0
# 2014-01-12                                   8                       26
# 2014-01-19                                  27                       24
# 2014-01-26                                  32                       35
# ...                                        ...                      ...
# 2023-07-30                                  57                       46
# 2023-08-06                                  49                       51
# 2023-08-13                                  61                       64
# 2023-08-20                                  53                       49
# 2023-08-27                                  62                       76
#
# Municipality                       Popayán                       Cúcuta
#                   Category: All categories     Category: All categories
# Week          Violence: (Cauca Department)  Violence: (North Santander)
# 2014-01-05                               0                           19
# 2014-01-12                              32                            9
# 2014-01-19                               0                            0
# 2014-01-26                               0                           43
# ...                                    ...                          ...
# 2023-07-30                              60                           23
# 2023-08-06                              84                           32
# 2023-08-13                              55                           28
# 2023-08-20                              50                           31
# 2023-08-27                              49                           45
#
# [506 rows x 10 columns]

# %%
# Remove the second level of the column index
merged_df.columns = merged_df.columns.droplevel(1)
merged_df.columns.name = None
merged_df = merged_df.iloc[1:,:]
merged_df = merged_df.reset_index().rename(columns={'index':'date'})
merged_df = merged_df[merged_df['date'] != 'Week']
merged_df
# Out:
#            date Medellín Cali Soacha Villavicencio Pasto Barranquilla  \
# 0    2014-01-05       35   25     31            66    26           27
# 1    2014-01-12       44   34     22            47    64           21
# 2    2014-01-19       46   40      0             0    16           49
# 3    2014-01-26       41   49    100             0    63           26
# 4    2014-02-02       57   49      0             0     0           40
# ..          ...      ...  ...    ...           ...   ...          ...
# 500  2023-07-30       59   50     56            41    41           38
# 501  2023-08-06       59   48     47            48    81           45
# 502  2023-08-13       68   44     47            47    43           55
# 503  2023-08-20       54   61     61            44    57           51
# 504  2023-08-27       67   69     47            54    41           57
#
#     Bucaramanga Ibagué Popayán Cúcuta
# 0            23      0       0     19
# 1             8     26      32      9
# 2            27     24       0      0
# 3            32     35       0     43
# 4            35     29       0     48
# ..          ...    ...     ...    ...
# 500          57     46      60     23
# 501          49     51      84     32
# 502          61     64      55     28
# 503          53     49      50     31
# 504          62     76      49     45
#
# [504 rows x 11 columns]

# %% [markdown]
# ### Get Epiweek

# %%
merged_df['date'] = pd.to_datetime(merged_df['date'])

# %%
merged_df['epiweek'] = merged_df['date'].apply(lambda x: Week.fromdate(x))

# %%
merged_df
# Out:
#           date Medellín Cali Soacha Villavicencio Pasto Barranquilla  \
# 0   2014-01-05       35   25     31            66    26           27
# 1   2014-01-12       44   34     22            47    64           21
# 2   2014-01-19       46   40      0             0    16           49
# 3   2014-01-26       41   49    100             0    63           26
# 4   2014-02-02       57   49      0             0     0           40
# ..         ...      ...  ...    ...           ...   ...          ...
# 500 2023-07-30       59   50     56            41    41           38
# 501 2023-08-06       59   48     47            48    81           45
# 502 2023-08-13       68   44     47            47    43           55
# 503 2023-08-20       54   61     61            44    57           51
# 504 2023-08-27       67   69     47            54    41           57
#
#     Bucaramanga Ibagué Popayán Cúcuta epiweek
# 0            23      0       0     19  201402
# 1             8     26      32      9  201403
# 2            27     24       0      0  201404
# 3            32     35       0     43  201405
# 4            35     29       0     48  201406
# ..          ...    ...     ...    ...     ...
# 500          57     46      60     23  202331
# 501          49     51      84     32  202332
# 502          61     64      55     28  202333
# 503          53     49      50     31  202334
# 504          62     76      49     45  202335
#
# [504 rows x 12 columns]

# %% [markdown]
# ### Save

# %%
merged_df.to_csv('Violence.csv', index=False)
