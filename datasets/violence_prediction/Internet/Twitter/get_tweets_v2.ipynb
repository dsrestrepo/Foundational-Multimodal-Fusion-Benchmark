# %%
import pandas as pd

# %%
coordinates = '../Coordinates/coordinates_center_top_10.csv'

coordinates = pd.read_csv(coordinates)
coordinates.head(10)
# Out:
#        lat      lng   Municipality  Municipality code  cases_number
# 0   6.2447 -75.5748       Medellín               5001         61367
# 1   3.4400 -76.5197           Cali              76001         37963
# 2   4.5781 -74.2144         Soacha              25754         14977
# 3   4.1425 -73.6294  Villavicencio              50001         14158
# 4   1.2136 -77.2811          Pasto              52001         13231
# 5  10.9639 -74.7964   Barranquilla               8001         12917
# 6   7.1186 -73.1161    Bucaramanga              68001         12696
# 7   4.4378 -75.2006         Ibagué              73001         11350
# 8   2.4411 -76.6061        Popayán              19001         11208
# 9   7.9075 -72.5047         Cúcuta              54001         10956

# %%
from dotenv import load_dotenv
import os

load_dotenv()

# Set Scraper API key
scraper_api_key = os.getenv('SCRAPER_API_KEY')

# %%
import requests
import json

# Set your search query
search_query = "violencia"

# Set your initial and end dates
initial_date = "2016-01-01"
end_date = "2023-01-01"

# Set your latitude and longitude
latitude = 2.4411
longitude = -76.6061

# Create a Scraper API request URL
api_url = "http://api.scraperapi.com/structured/twitter/search"

# Make the request
try:
    response = requests.get(api_url, params={
        "api_key": scraper_api_key,
        "query": search_query,
        "ini": initial_date,
        "end": end_date,
        "latitude": latitude,
        "longitude": longitude
    })
except Exception as e:
    print(e)

# Parse the JSON response
data = json.loads(response.content)

# %%
twitter_data = []

# Extract the tweets
tweets = data["organic_results"]

# Iterate over the tweets and print the text
for tweet in tweets:
    twitter_data.append(tweet)

# %%
pd.DataFrame(twitter_data)
# Out:
#    position                                              title  \
# 0         0  Delegación del Gob. contra la Violencia de Género
# 1         1  Política relativa al discurso de incitación a ...
# 2         2                           OVV (@ovv_violencia) / X
# 3         3      Frente Nacional contra Violencia Vicaria A.C.
# 4         4   Reglas y políticas - Twitter Help Center - X.com
# 5         5  violencia» se suele usar en singular, es válid...
# 6         6  Informe Mensual de Avances de la Alerta por Vi...
# 7         7  Programa TUNIDAD: ¡Todas contra la violencia! / X
# 8         8                                  ACNUR El Salvador
# 9         9                 Banco Interamericano de Desarrollo
#
#                                              snippet               highlighs  \
# 0  Hoy ha tenido lugar el 6º #ComitéDeCrisis para...             [violencia]
# 1  No puedes amenazar, incitar, glorificar o expr...             [violencia]
# 2  Observatorio Venezolano de Violencia Director:...             [Violencia]
# 3  Si vives en QRO o en algún lugar cercano no de...             [violencia]
# 4  Seguridad y ciberdelincuencia Políticas que co...             [violencia]
# 5  Nov 27, 2019 — #RAEconsultas Aunque «violencia...             [violencia]
# 6  Log in · Sign up. Embedded video. Gobierno de ...             [Violencia]
# 7      Programa TUNIDAD: ¡Todas contra la violencia!             [violencia]
# 8  Dec 5, 2022 — Las mujeres y niñas sufren viole...  [violencia, violencia]
# 9  May 12, 2023 — El crimen y la violencia afecta...             [violencia]
#
#                                                 link  \
# 0                       https://twitter.com/DelGobVG
# 1  https://help.twitter.com/es/rules-and-policies...
# 2                  https://twitter.com/ovv_violencia
# 3                    https://twitter.com/FNCVVICARIA
# 4     https://help.twitter.com/es/rules-and-policies
# 5  https://twitter.com/RAEinforma/status/11996029...
# 6  https://mobile.twitter.com/i/broadcasts/1LyGBq...
# 7  https://mobile.twitter.com/i/broadcasts/1RDxla...
# 8  https://mobile.twitter.com/ACNURElSalvador/sta...
# 9  https://twitter.com/el_BID/status/165699263148...
#
#                              displayed_link  \
# 0            https://twitter.com › DelGobVG
# 1  https://help.twitter.com › violent-sp...
# 2       https://twitter.com › ovv_violencia
# 3         https://twitter.com › FNCVVICARIA
# 4  https://help.twitter.com › rules-and-...
# 5              https://twitter.com › status
# 6    https://mobile.twitter.com › broadc...
# 7    https://mobile.twitter.com › broadc...
# 8       https://mobile.twitter.com › status
# 9     https://twitter.com › el_BID › status
#
#                                            sitelinks
# 0  {'inline': [{'title': 'Translate this page', '...
# 1  {'inline': [{'title': 'Translate this page', '...
# 2                                                NaN
# 3  {'inline': [{'title': 'Translate this page', '...
# 4  {'inline': [{'title': 'Translate this page', '...
# 5  {'inline': [{'title': 'Translate this page', '...
# 6  {'inline': [{'title': 'Translate this page', '...
# 7  {'inline': [{'title': 'Translate this page', '...
# 8  {'inline': [{'title': 'Translate this page', '...
# 9  {'inline': [{'title': 'Translate this page', '...

# %%
data
# Out:
# {'search_information': {'query_displayed': 'site:twitter.com "violencia"',
#   'total_results': 1720000,
#   'time_taken_displayed': 0.5},
#  'organic_results': [{'position': 0,
#    'title': 'Delegación del Gob. contra la Violencia de Género',
#    'snippet': 'Hoy ha tenido lugar el 6º #ComitéDeCrisis para analizar los asesinatos machistas de septiembre     ‼️ 10 mujeres han sido asesinadas por violencia de género y 5\xa0...',
#    'highlighs': ['violencia'],
#    'link': 'https://twitter.com/DelGobVG',
#    'displayed_link': 'https://twitter.com › DelGobVG',
#    'sitelinks': {'inline': [{'title': 'Translate this page',
#       'link': 'https://translate.google.com/translate?hl=en&sl=es&u=https://twitter.com/DelGobVG&prev=search&pto=aue'}]}},
#   {'position': 1,
#    'title': 'Política relativa al discurso de incitación a la violencia de X',
#    'snippet': 'No puedes amenazar, incitar, glorificar o expresar un deseo de daño o violencia. X es un lugar donde las personas pueden expresarse, aprender acerca de qué\xa0...',
#    'highlighs': ['violencia'],
#    'link': 'https://help.twitter.com/es/rules-and-policies/violent-speech',
#    'displayed_link': 'https://help.twitter.com › violent-sp...',
#    'sitelinks': {'inline': [{'title': 'Translate this page',
#       'link': 'https://translate.google.com/translate?hl=en&sl=es&u=https://help.twitter.com/es/rules-and-policies/violent-speech&prev=search&pto=aue'}]}},
#   {'position': 2,
#    'title': 'OVV (@ovv_violencia) / X',
#    'snippet': 'Observatorio Venezolano de Violencia Director: Roberto Briceño-León E-mail: ovvcontacto@gmail.com. Non-Governmental & Nonprofit Organization Venezuela\xa0...',
#    'highlighs': ['Violencia'],
#    'link': 'https://twitter.com/ovv_violencia',
#    'displayed_link': 'https://twitter.com › ovv_violencia'},
#   {'position': 3,
#    'title': 'Frente Nacional contra Violencia Vicaria A.C.',
#    'snippet': 'Si vives en QRO o en algún lugar cercano no desaproveches está oportunidad para entender y aprender más de la violencia vicaria y saber q hacer en caso de\xa0...',
#    'highlighs': ['violencia'],
#    'link': 'https://twitter.com/FNCVVICARIA',
#    'displayed_link': 'https://twitter.com › FNCVVICARIA',
#    'sitelinks': {'inline': [{'title': 'Translate this page',
#       'link': 'https://translate.google.com/translate?hl=en&sl=es&u=https://twitter.com/FNCVVICARIA&prev=search&pto=aue'}]}},
#   {'position': 4,
#    'title': 'Reglas y políticas - Twitter Help Center - X.com',
#    'snippet': 'Seguridad y ciberdelincuencia Políticas que controlan el cumplimiento de nuestros principios contra el abuso, el acoso, la violencia y las acciones delictivas\xa0...',
#    'highlighs': ['violencia'],
#    'link': 'https://help.twitter.com/es/rules-and-policies',
#    'displayed_link': 'https://help.twitter.com › rules-and-...',
#    'sitelinks': {'inline': [{'title': 'Translate this page',
#       'link': 'https://translate.google.com/translate?hl=en&sl=es&u=https://help.twitter.com/es/rules-and-policies&prev=search&pto=aue'}]}},
#   {'position': 5,
#    'title': 'violencia» se suele usar en singular, es válido y frecuente ...',
#    'snippet': 'Nov 27, 2019 — #RAEconsultas Aunque «violencia» se suele usar en singular, es válido y frecuente su uso en plural; por ejemplo, para referirse a una\xa0...',
#    'highlighs': ['violencia'],
#    'link': 'https://twitter.com/RAEinforma/status/1199602907626311680',
#    'displayed_link': 'https://twitter.com › status',
#    'sitelinks': {'inline': [{'title': 'Translate this page',
#       'link': 'https://translate.google.com/translate?hl=en&sl=es&u=https://twitter.com/RAEinforma/status/1199602907626311680&prev=search&pto=aue'}]}},
#   {'position': 6,
#    'title': 'Informe Mensual de Avances de la Alerta por Violencia ...',
#    'snippet': 'Log in · Sign up. Embedded video. Gobierno de la Ciudad de México. Informe Mensual de Avances de la Alerta por Violencia contra las Mujeres.',
#    'highlighs': ['Violencia'],
#    'link': 'https://mobile.twitter.com/i/broadcasts/1LyGBqQXLMaKN',
#    'displayed_link': 'https://mobile.twitter.com › broadc...',
#    'sitelinks': {'inline': [{'title': 'Translate this page',
#       'link': 'https://translate.google.com/translate?hl=en&sl=es&u=https://mobile.twitter.com/i/broadcasts/1LyGBqQXLMaKN&prev=search&pto=aue'}]}},
#   {'position': 7,
#    'title': 'Programa TUNIDAD: ¡Todas contra la violencia! / X',
#    'snippet': 'Programa TUNIDAD: ¡Todas contra la violencia!',
#    'highlighs': ['violencia'],
#    'link': 'https://mobile.twitter.com/i/broadcasts/1RDxlaZmymlKL',
#    'displayed_link': 'https://mobile.twitter.com › broadc...',
#    'sitelinks': {'inline': [{'title': 'Translate this page',
#       'link': 'https://translate.google.com/translate?hl=en&sl=es&u=https://mobile.twitter.com/i/broadcasts/1RDxlaZmymlKL&prev=search&pto=aue'}]}},
#   {'position': 8,
#    'title': 'ACNUR El Salvador',
#    'snippet': 'Dec 5, 2022 — Las mujeres y niñas sufren violencia de género globalmente  . La violencia se agrava durante el desplazamiento. En #ElSalvador     y en todo\xa0...',
#    'highlighs': ['violencia', 'violencia'],
#    'link': 'https://mobile.twitter.com/ACNURElSalvador/status/1599780833979641856',
#    'displayed_link': 'https://mobile.twitter.com › status',
#    'sitelinks': {'inline': [{'title': 'Translate this page',
#       'link': 'https://translate.google.com/translate?hl=en&sl=es&u=https://mobile.twitter.com/ACNURElSalvador/status/1599780833979641856&prev=search&pto=aue'}]}},
#   {'position': 9,
#    'title': 'Banco Interamericano de Desarrollo',
#    'snippet': 'May 12, 2023 — El crimen y la violencia afectan desproporcionadamente a #Mujeres y #Niñas en la región. ¿Quieres conocer las soluciones y estrategias más\xa0...',
#    'highlighs': ['violencia'],
#    'link': 'https://twitter.com/el_BID/status/1656992631489191936',
#    'displayed_link': 'https://twitter.com › el_BID › status',
#    'sitelinks': {'inline': [{'title': 'Translate this page',
#       'link': 'https://translate.google.com/translate?hl=en&sl=es&u=https://twitter.com/el_BID/status/1656992631489191936&prev=search&pto=aue'}]}}],
#  'pagination': {'load_more_url': 'http://api.scraperapi.com/?url=https%3A%2F%2Fwww.google.com%2Fsearch%3Fq%3Dsite%3Atwitter.com%2B%2522violencia%2522%26sca_esv%3D571003301%26gl%3DUS%26ei%3DoOUeZaq-MK6i5NoPsrCLkAk%26start%3D10%26sa%3DN&autoparse=true',
#   'pages_count': 1}}
